# %% [markdown]
# Extração de Dados HTML
#
# Fonte: H&M <https://www2.hm.com/en_us/men/products/jeans.html>

# %% [markdown]
# Dados a serem coletados para criação de tabela:
#
# - id
# - product_name
# - product_type
# - product_color
# - composition
# - price

# %%
import requests

import pandas as pd

import numpy as np

import math

from datetime import datetime

from bs4 import BeautifulSoup

# %%
url1 = 'https://www2.hm.com/en_us/men/products/jeans.html'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get( url1, headers=headers )

# %%
page
# Out:
# <Response [200]>

# %%
# Retornando o HTML da página

page.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="en-US" is-in-aem="false" class="no-js en-us" ng-app="hmApp" >\n    \n\n\n    <head>\r\n    \r\n  <link rel="dns-prefetch" href="https://s1-cdn.hm.com"/>\r\n  <link rel="preconnect" href="https://s1-cdn.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://tags.tiqcdn.com"/>\r\n  <link rel="preconnect" href="https://tags.tiqcdn.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://lp2.hm.com"/>\r\n  <link rel="preconnect" href="https://lp2.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://cdn-pci.optimizely.com"/>\r\n  <link rel="preconnect" href="https://cdn-pci.optimizely.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://s.go-mpulse.net"/>\r\n  <link rel="preconnect" href="https://s.go-mpulse.net" crossorigin/>\r\n\n\t\n\t\t<script type="text/javascript" src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js"></script>\n\t\t<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422"></script>\n    \t\n    \t\t<script type="text/javascript">function OptanonWrapper() {\r\n            if (window.location.pathname.includes(\'customer-service\') &&\r\n                (window.location.pathname.includes(\'en_us\') || window.location.pathname.includes(\'es_us\'))) {\r\n                var newItem = document.createElement("div");\r\n                newItem.id = \'svgButtons\';\r\n\r\n                // Up svg\r\n                const iconSvgUp = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathUp = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgUp.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgUp.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgUp.setAttribute(\'width\', 16);\r\n                iconSvgUp.setAttribute(\'height\', 16);\r\n                iconSvgUp.setAttribute(\'title\', \'Expand Cookie banner\');\r\n                iconPathUp.setAttribute(\r\n                    \'d\',\r\n                    \'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z\'\r\n                );\r\n\r\n                iconPathUp.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)\');\r\n                iconSvgUp.appendChild(iconPathUp);\r\n                iconSvgUp.addEventListener(\'click\', () => handleClick(\'Up\'));\r\n                newItem.appendChild(iconSvgUp);\r\n                iconSvgUp.style.float = \'right\';\r\n\r\n                // Down svg\r\n                const iconSvgDown = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathDown = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgDown.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgDown.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgDown.setAttribute(\'width\', 16);\r\n                iconSvgDown.setAttribute(\'height\', 16);\r\n                iconSvgDown.setAttribute(\'title\', \'Collapse Cookie banner\');\r\n                iconPathDown.setAttribute(\r\n                    \'d\',\r\n                    \'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z\'\r\n                );\r\n\r\n                iconPathDown.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)\');\r\n                iconSvgDown.appendChild(iconPathDown);\r\n             ...

# %%
# Instanciando objeto Beautiful Soup

soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js en-us" is-in-aem="false" lang="en-US" ng-app="hmApp">
# <head>
# <link href="https://s1-cdn.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s1-cdn.hm.com" rel="preconnect"/>
# <link href="https://tags.tiqcdn.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://tags.tiqcdn.com" rel="preconnect"/>
# <link href="https://lp2.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://lp2.hm.com" rel="preconnect"/>
# <link href="https://cdn-pci.optimizely.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cdn-pci.optimizely.com" rel="preconnect"/>
# <link href="https://s.go-mpulse.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s.go-mpulse.net" rel="preconnect"/>
# <script src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-document-language="true" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">function OptanonWrapper() {
#             if (window.location.pathname.includes('customer-service') &&
#                 (window.location.pathname.includes('en_us') || window.location.pathname.includes('es_us'))) {
#                 var newItem = document.createElement("div");
#                 newItem.id = 'svgButtons';
#
#                 // Up svg
#                 const iconSvgUp = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathUp = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgUp.setAttribute('fill', '#222222');
#                 iconSvgUp.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgUp.setAttribute('width', 16);
#                 iconSvgUp.setAttribute('height', 16);
#                 iconSvgUp.setAttribute('title', 'Expand Cookie banner');
#                 iconPathUp.setAttribute(
#                     'd',
#                     'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z'
#                 );
#
#                 iconPathUp.setAttribute(
#                     'transform', 'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)');
#                 iconSvgUp.appendChild(iconPathUp);
#                 iconSvgUp.addEventListener('click', () => handleClick('Up'));
#                 newItem.appendChild(iconSvgUp);
#                 iconSvgUp.style.float = 'right';
#
#                 // Down svg
#                 const iconSvgDown = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathDown = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgDown.setAttribute('fill', '#222222');
#                 iconSvgDown.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgDown.setAttribute('width', 16);
#                 iconSvgDown.setAttribute('height', 16);
#                 iconSvgDown.setAttribute('title', 'Collapse Cookie banner');
#                 iconPathDown.setAttribute(
#                     'd',
#                     'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z'
#                 );
#
#                 iconPathDown.setAttribute(
#                     'transform', 'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)');
#                 iconSvgDown.appendChild(iconPathDown);
#                 iconSvgDown.addEventListener('click', () => handleClick('Down'));
#                 newItem.appendChild(iconSvgDown);
#                 iconSvgDown.style.display = 'none'
#                 iconSvgDown.style.float = 'right';
#                 iconSvgDown.style.marginBottom = '16px';
#
#                 //Adding svg's to the top of title in banner
#                 var list = document.getElementById("onetrust-banner-sdk").childNodes[0];
#                 list.insertBefore(newItem, list.childNodes[0]);
#                 list.style.padding = '20px 40px 40px 40px';
#
#                 document.getElementById('onetrust-group-container').style.display = 'none';
#                 document.getElementById('onetrust-button-group-parent').style.display = 'none';
#
#                 function handleClick(text) {
#                     let buttons = document.getElementById('svgButtons');
#                     if (text === 'Up') {
#                         document.getElementById('onetrust-group-container').style.display = 'block';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'block';
#                         buttons.firstChild.style.display = 'none';
#                         buttons.lastChild.style.display = 'block';
#                     } else {
#                         document.getElementById('onetrust-group-container').style.display = 'none';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'none';
#                         buttons.firstChild.style.display = 'block';
#                         buttons.lastChild.style.display = 'none';
#                     }
#                 }
#             }
#         }</script>
# <link as="script" href="https://s1-cdn.hm.com/global/frontend/loader.js" rel="preload"/>
# <script src="https://s1-cdn.hm.com/global/frontend/loader.js" type="text/javascript"></script>
# <link href="https://s1-cdn.hm.com/global/fonts/4.0.15/hm/css/fonts_en_us.css" rel="stylesheet"/>
# <style type="text/css">/* atf version: 0.19.3 */html{overflow:hidden}body{line-height:1.2307692308;font-size:.8125rem;font-family:"HM Sans Regular","HMSansHebrew-Regular","ヒラギノ角ゴ Pro W3","Hiragino Kaku Gothic Pro",Osaka,"メイリオ",Meiryo,"ＭＳ Ｐゴシック","MS PGothic",sans-serif;font-weight:400;text-transform:none;background-color:#faf9f8;margin:0;color:#222;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;overflow-x:hidden}body.mobile-app::before{content:"";display:block;position:fixed;width:100%;height:100vh;background-color:#faf9f8;z-index:10000}a{color:inherit}button{border:0;background-color:transparent}.hide-content{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}.header-global{background:#faf9f8;height:100vh;left:0;padding:21px 0;position:fixed;top:0;width:100%;z-index:1001}.menu{position:relative;display:inline-block;width:100%}.menu a{text-decoration:none}.menu__hm{display:block;width:43px;height:30px;text-indent:-9999px;overflow:hidden;margin:0 0 0 53px}.menu__hm::before{background-image:url("data:image/svg+xml;charset=US-ASCII,%3Csvg%20width%3D%22370%22%20height%3D%22244%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%3E%3Ctitle%3E1.%20Foundation%2FLogotypes%2FH%26amp%3BM%2FRed%3C%2Ftitle%3E%3Cdefs%3E%3Cpath%20d%3D%22M259.895%207.413c13.424-6.618%2020.087-5.737%2020.232.946.19%208.7-1.098%2020.23-2.016%2028.604-4.983%2045.423-13.32%2082.543-13.954%20129.19%2021.94-56.802%2040.345-96.278%2064.03-144.909%207.53-15.47%2012.325-12.593%2018.503-15.343%2024.082-10.715%2024.984-4.133%2021.837%208.95-11.686%2048.552-41.54%20201.376-46.114%20224.907-1.328%206.807-8.715%203.923-10.644%201.26-8.57-11.85-18.225-12.036-17.14-19.919%205.37-39.233%2024.71-137.666%2029.75-160.863-25.719%2052.696-52.37%20118.566-66.053%20155.914-2.907%207.931-8.188%207.35-11.48%201.546-4.63-8.15-13.61-12.312-15.093-21.943-4.702-30.628%205.37-89.003%206.773-125.936-13.994%2040.342-37.49%20118.67-47.782%20154.057-4.256%2014.643-18.382%2012.253-14.627-2.018%2015.642-59.389%2049.326-164.425%2063.915-202.198%203.427-8.874%2012.406-8.569%2019.863-12.245zM174.6.115c4.26%201.025%203.913%206.05%201.31%2012.912-7.682%2020.247-18.335%2046.847-30.516%2078.212%207.658-.874%2011.811-1.17%2011.811-1.17%2010.994-1.358%2013.041%204.139%209.946%209.99-2.466%204.664-5.436%201.554-15.724%2016.89-5.796%208.642-15.259%2010.924-20.515%2012.076-12.662%2033.523-26.23%2070.916-39.415%20110.77-1.919%205.804-7.524%204.532-9.209%202.174-6.192-8.647-10.758-8.933-15.558-15.927-.577-1.132-1.706-2.672-1.027-5.448%203.53-14.425%2012.901-44.067%2027.156-83.091-17.958%203.892-37.387%208.076-45.408%209.94-9.626%2025.445-19.014%2050.967-27.908%2076.18-5.518%2015.64-19.88%2012.617-14.84-2.165%208.028-23.548%2016.89-48.004%2025.776-71.72-9.948-1.063-13.313-8.088-18.873-13.958-2.147-2.267-6.828-1.948-9.12-5.127-4.123-5.711-3.712-8.248%205.81-10.996a955.318%20955.318%200%200%201%2037.464-9.998c16.09-41.524%2030.63-77.144%2038.38-96.151C90.114-1.138%20105.514.226%2099.664%2014.674c-11.889%2029.363-24.079%2059.867-36.11%2090.799a880.98%20880.98%200%200%201%2044.748-8.87%202312.644%202312.644%200%200%201%2034.62-83.968c.845-1.937%203.31-4.678%205.878-5.118%208.092-1.385%2021.251-8.498%2025.8-7.402zm-27.552%20190.077c1.265-.773%202.524-1.715%203.767-2.75a756.514%20756.514%200%200%201-2.82-8.468%20139.528%20139.528%200%200%200-2.752%203.638c-5.386%207.396-2.197%2010.028%201.805%207.58zm7.167-35.065c6.67-7.53-6.516-10.681-3.48.836.17.65.382%201.413.62%202.254a98.19%2098.19%200%200%200%202.86-3.09zm6.941%2022.695c6.602-5.721%2012.908-.046%206.38%209.628-1.404%202.08-2.99%204.318-4.729%206.522a193.17%20193.17%200%200%200%202.146%205.877c3.375%208.654-5.488%2010.824-8.345%203.656-.25-.626-.51-1.297-.778-1.995-5.387%204.772-11.618%207.777-18.275%205.707-10.954-3.407-13.74-18.83-3.514-30.711%204.103-4.767%207.191-8.074%209.771-10.716a251.947%20251.947%200%200%201-1.8 ...
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.css" type="text/css">
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.js"></script>
# <![endif]-->
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/jquery.min.js"></script>
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/head.min.14.1.60.js"></script>
# <!-- to include grunticon -->
# <script>var clientlibsVersion = '.14.1.60';</script>
# <!-- to include grunticon -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script async="" src="https://idservice.hm.com/"></script>
# <script type="text/javascript"></script><script src="https://www2.hm.com/optimizelyjs/s/hm_us.js"></script>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script type="application/ld+json">
#
# 		{
# 		"@context" : "https://schema.org",
# 		"@type" : "BreadcrumbList",
# 		"itemListElement":[
# 		       {"@type":"ListItem",
# 				"position":"1",
# 				"name":"HM.com",
# 				"item": "https://www2.hm.com/en_us/index.html"
# 		        },
#
# 		       {"@type":"ListItem",
# 				"position":"2",
# 				"name":"Men",
# 				"item": "https://www2.hm.com/en_us/men.html"
# 		        },
#
# 		       {"@type":"ListItem",
# 				"position":"3",
# 				"name":"Jeans"
# 		        }
#
# 		]}
#
# </script>
# <meta content="/en_us/men/shop-by-product/jeans" name="contentPath">
# <meta content="Add classic cool to your wardrobe with H&amp;M's collection of men's jeans. Shop online for skinny, slim and straight styles in a range of colors and washes." name="description">
# <meta content="Men's Jeans | Ripped &amp; Skinny Jeans | H&amp;M US" property="og:title"/>
# <meta content="Add classic cool to your wardrobe with H&amp;M's collection of men's jeans. Shop online for skinny, slim and straight styles in a range of colors and washes." property="og:description"/>
# <meta content="H&amp;M" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www2.hm.com/en_us/men/products/jeans.html" property="og:url"/>
# <meta content="https://www2.hm.com/content/dam/courtesypageimages/down_for_maintenance.jpeg" property="og:image"/>
# <meta content="1433700643510498" property="fb:app_id"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www2.hm.com/en_us/men/products/jeans.html" rel="canonical">
# <title>Men's Jeans | Ripped &amp; Skinny Jeans | H&amp;M US</title>
# <meta content="hmgoe://www2.hm.com/en_us/men/products/jeans.html" property="al:ios:url">
# <meta content="834465911" property="al:ios:app_store_id">
# <meta content="H&amp;M App" property="al:ios:app_name">
# <meta content="hmgoe://www2.hm.com/en_us/men/products/jeans.html" property="al:android:url">
# <meta content="com.hm.goe.prd.am" property="al:android:package">
# <meta content="H&amp;M" property="al:android:app_name"/>
# <script src="/en_us/metrics/default/touchpoint.js" type="text/javascript"></script>
# <meta property="og:open_graph_title"/>
# <meta property="og:open_graph_description"/>
# <meta property="og:open_graph_url"/>
# <meta property="og:open_graph_image"/>
# <meta property="og:open_graph_video"/>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="EPMEN-VPFQ4-GM3WK-22BJD-TU9B7",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"EPMEN-VPFQ4-GM3WK-22BJD-TU9B7";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="fia4weef52naakqce3ybwaabtrrjmbjs-f-042bc8818-clienttons-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"271055","ak.ai":parseInt("171241",10),"ak.ol":"0","ak.cr":64,"ak.ipv":6,"ak.proto":"http/1.1","ak.rid":"68990145","ak.r":36989,"ak.a2":n,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"2a01:cb10:85ee:9a00::","ak.cport":61046,"ak.gh":"92.123.238.85","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1653998898","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"326","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></meta></meta></meta></meta></meta></link></meta></meta></head><body class="subdepartment-page" ng-class="{pre_shopping_sale_countdown:preshoppingStartingSo ...
# <div class="dictionary parbase"></div>
# <div style="">
# <script type="text/javascript">
#
#         var hm = hm || {};
#         hm.options = hm.options || {};
#         hm.options.tealiumPageId = 'Men : Shopbyproduct : Jeans : Viewall';
#
# </script><!-- Header -->
# <script>
#     var hm = hm || {};
#
#     (function(hm){
#
#     	hm.MultiCountry = function() {
#
#     		function readCookieValue(name) {
#
#     			var cookieAll = document.cookie.split(';'),
#     				cookieValue;
#     			if(cookieAll && cookieAll.length){
#     				cookieAll.some(function(entry){
#     					entry = entry.trim();
#     					var cookiePair = entry.split('=');
#     					if(cookiePair[0]==name){
#     						cookieValue = decodeURIComponent(cookiePair[1]);
#     						return true;
#     					}
#     				});
#     			}
#     			return cookieValue;
#     		};
#
#     		this.getCountryName = function getCountryCode(cookieName) {
#     			var cookieValue = readCookieValue(cookieName);
#     			return cookieValue;
#     		};
#
#     		this.getCountryCode = function getCountryCode(cookieName) {
#
#     			 var cookieValue = readCookieValue(cookieName),
#     				countryCode = "";
#     			if(cookieValue) {
#     				var match = /(?:^[a-z]{2}_)?([A-Z]{2})$/.exec(cookieValue);
#     				if(match) {
#     					countryCode = match[1];
#     				}
#     			}
#     			return countryCode;
#     		};
#
#     		this.getLocale = function getLocale(cookieName, language) {
#
#     		   var locale = "";
#     		   if(!language) {
#     				var cookieValue = readCookieValue(cookieName);
#     				if(cookieValue && cookieValue.search(/^[a-z]{2}_[A-Z]{2}$/) == 0) {
#     					locale = cookieValue;
#     				}
#     		   } else {
#     				var country = this.getCountryCode(cookieName);
#     				if(country.length) {
#     					locale =  language + "_" + country;
#     				}
#     		   }
#     		   return locale;
#     		};
#
#     		this.getLanguage = function getLanguage(cookieName) {
#     		   var language = this.getLocale(cookieName);
#     		   if(!language || !language.length) {
#     				return "";
#     		   }
#     		   else {
#     				return language.substring(0,2);
#     		   }
#     		};
#
#     		this.createCookie = function createCookie(cookieName, language, country) {
#     	        var d = new Date(),
#     			exdays = 182;
#     			d.setTime(d.getTime() + (exdays*24*60*60*1000));
#     			var expires = "expires="+ d.toUTCString();
#     			var userAgent = navigator.userAgent;
#     			var userAgentLowerCase;
#
#     			if(userAgent !== "undefined" && userAgent){
#     				userAgentLowerCase = userAgent.toLowerCase();
# 					if(userAgentLowerCase.includes("chrome")){
# 	    	        	var cookie = cookieName + "=" + language + "_" + country + "; " + expires + ";SameSite=None; Secure; domain=.hm.com; path=/";
# 	    	        } else {
# 						var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	        }
# 	    	    } else {
# 					var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	    }
#     	        return cookie;
#     		};
#
#     	};
#
#     	hm.multiCountry = new hm.MultiCountry();
#     })(hm);
#
#
#     hm.options = hm.options || {};
#     hm.options.omnicredit = hm.options.omnicredit || {};
#     hm.options.klarna = hm.options.klarna || {};
#     var wpwlOptions = window.wpwlOptions || {};
#
#     var localeInfo ={};
#     localeInfo.locale = "en_US";
# 	localeInfo.country = "US";
#
#     hm.i18n = hm.i18n || {};
#
#     hm.options.forceUtagForAndroid = false;
#     hm.options.forceUtagForIOS = false;
#
#     hm.options.isLoyaltyMarket = 'true';
#
#     hm.options.isCiamEnabled = 'false';
#
#     hm.options.product = {
#       removeFromCartServiceUrl: 'remove_from_cart_response.json',
#       country: 'hm-us',
#       locale: 'en_us',
#       getFavoritesService: '/en_us/favourites/productCodes',
#       addFavoriteService: '/en_us/favourites/addItem',
#       removeFavoriteService: '/en_us/favourites/removeItem',
# 	  addToCartServiceUrl: '/en_us/cart/add',
# 	  esalesServicePathname: '/pra/panel/product-detail-page',
# 	  clubMemberPriceLabel: 'Member price',
# 	  modelHeightGarmentSizePDPLabel: 'The model is {0} and wears a size {1}',
# 	  sizePDPLabel: 'Size'
#     };
#
#     var productAvailabilityServiceUrl = '/hmwebservices/service/product/{site_code}/availability/{product_code}.json';
# 	var countryForAvailability = hm.options.product.locale;
# 	if(countryForAvailability.indexOf("_")>=0){
# 		countryForAvailability = hm.options.product.locale.split("_")[1];
# 	}
#     productAvailabilityServiceUrl = productAvailabilityServiceUrl.replace("{site_code}",countryForAvailability);
#     hm.options.product.productAvailabilityServiceUrl = productAvailabilityServiceUrl;
#
#     hm.options.clubSetup = {
#     		clubSetupCountry : 'hm-us',
#     		clubSetupTierLevelLimit : '500',
#     		clubSetupCashBackEnabled : 'true',
#     		clubSetupAmount : '5',
#     		clubSetupCashBackCapYear : '99',
#     		clubSetupCashBackCapRolling : '25',
#     		clubSetupCashBackPoints : '200',
#     		clubSetupRatingReviewEnabled : 'false',
#     		clubSetupRatingreview : '0',
#     		clubSetupReviewPointsCapRolling : '0'
#
#     };
#     hm.options.clubUpgrade = {
#     	confirmationMessage: 'You&#039;re now a member!'
#     };
#
#     hm.options.esalesPra10 = {
#     		url: '/en_us/pra/panel/pra10'
#     };
#
#     hm.options.praSlideNoText = {
#    		slideBulletText: '[slideNumberLabel]'
#   	};
#
#     hm.options.gdpr = {
#     	    enabled: 'false',
#     	    dateStart: '2018-05-14T00:00:00.000+02:00',
#     	    dateEnd: '2021-05-01T00:00:00.000+02:00',
#     	    url:'https://www2.hm.com/en_us/customer-service/legal-and-privacy/privacy-link.html'
#     	  };
#
#     hm.options.orders = {
#     	    getOrders: '/mock/getOrders',
#     	    offset: '5',
#     	    missingImageUrl: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/kaff.png'
#     	  };
#     hm.options.pra = {
#     		pra1: '/en_us/pra/panel/product-detail-page',
#     	    pra6: '/en_us/pra/panel/sub-department-page',
#    	     	pra10: '/en_us/pra/panel/pra10',
#     	   	pra11: '/en_us/pra/panel/sale-department-page',
#     	    pra3: '/en_us/pra/panel/shopping-bag-page',
#     	    pra4: '/en_us/pra/panel/shopping-bag-page'
#          };
#     hm.options.omnicredit.isOmnicreditMarket = true;
#
#     hm.options.klarna.showAlerts = true;
#     hm.options.enableQuestionairre = false;
#
#        hm.i18n = {
#        	sizeGuide:  {
# 			   back: 'Back',
# 			   sizeGuide: 'Size Guide',
# 			   findMySize: 'Find my size',
# 			   howToMeasure: 'HOW TO MEASURE',
# 			   selectSizeRange: 'Select Size Range',
# 			   sizeGuideLinkText: 'SIZE GUIDE - ALL PRODUCTS',
# 			   noSizeGuideTitle: 'Oh, hello there!',
# 			   noSizeGuideDescription: 'We don&#039;t have a size guide available for this product at the moment.',
# 			   noSizeGuideClose: 'CLOSE'
# 		},
#    		 favorite: {
#    	   	        favoritesErrorText: 'Sorry, we were unable to move  your item to Favorites. Please try again later.',
#    	   	        addToFavoritesErrorHeading: 'Item not added to Favorites',
#    	   	        removeFavoritesErrorHeading: 'ERROR WHEN REMOVING FAVORITE',
#    	   	        moveToBagErrorHeading: 'Item not moved to your Shopping Bag',
#    	   	     	moveToFavoritesErrorHeading: 'Oops… Favorites is full',
#    	   	    	fullFavoritesListError: 'Sorry, Favorites is full so we can&#039;t add this item. If you really love this item, delete one of your saved items to make room!',
#    	   	        fullFavoritesListErrorHeading: 'Oops… Favorites is full',
#    	   	    	activeText: 'Saved to favorites',
#    	  	      	inactiveText: 'Not saved to favorites'
#    	   	},
#    	 	quickbuy: {
#    	   	      viewMore: 'Show more',
#    	   	      add: 'Add to bag',
#    	   	      selectSize: 'Select size',
#    	   	      fewPiecesLeft: 'Few pieces left',
#    	   	      soldOut: 'Sold out',
#     	 	  sizeGuide: 'Size guide'
#    	   	    },
#    	 	getthelook: {
#    	   	      title: 'Get the look!',
#    	   	      add: 'ADD TO BAG',
#    	   	      addedToBag: 'Added to bag'
#    	   	    },
#    	 	gdpr: {
# 	      	headerText: 'WE CARE ABOUT YOUR PRIVACY!',
#    	  		bodyText:'Your privacy is important to us which is why we want to inform you on our updated Privacy Notice. To give you a more transparent and clear information on how we process your personal data, we have divided the Privacy Notice into different chapters. Depending on if you are a subscriber, member or if you have an H&amp;M Account, different parts of the notice will apply to you. In each chapter, we describe in more detail what personal data we have about you and how we use it. We have also increased the information on your rights, for example how to get access to your data and how you can request to terminate the usage of your data.',
# 	      	linkText: 'You can find our Privacy Notice here',
# 	      	buttonText: 'Ok'
#    		},
# 	    luminaires: {
# 	    		regulationText: 'Regulation (EU) No: 874/2012',
# 	    		energyLabelling: 'Energy rating',
# 	    		compatible: 'This luminaire is compatible with bulbs of energy classes:',
# 	    		energyDeclaration: 'ENERGY RATING',
# 	    		imageNumber: '874/2012'
#
# 	   	},
#     	turnTo: {
# 		    labels: {
# 		    	reviewesLabel: "REVIEWS",
# 		    	finishReview: "FINISH THIS REVIEW",
# 		    	submitReviewCTA: "Send my review",
# 		    	helpHeading: "Help us rate your latest purchase",
# 		    	greeting: "HI",
# 		    	shareExperienceCta: "Share your experience",
# 		    	shareExperienceCtaText: "and help others make great  decisions, please rate your latest purchase",
# 		    	productSatHeading: "Product satisfaction",
# 		    	productSatText: "Rate your product satisfaction",
# 		    	ratingHeading: "Rating",
# 		    	sizeFitHeading: "SIZE AND FIT",
# 		    	myProfileHeading: "My profile",
# 		    	myProfileText: "Help others make great decisions, tell them a little about yourself.",
# 		    	reviewTextLong: "What do you think? People talk about quality, look and feel.",
# 		    	thankYouHeading: "THANK YOU!",
# 		    	thankYouText: "Your feedback is much appreciated",
# 		    	moreReviewCta: "Your reviews are really valuable",
# 		    	moreReviewCta2: "Let&#039;s go for another one!",
# 		    	othersLabel: "What other customers think based on",
# 		    	numberReviews: "{xx} reviews",
# 		    	numberReviewsMenu: "Reviews ({xx})",
# 		    	numberComments: "{xx} comments",
# 		    	othersHeading: "WHAT OTHER CUSTOMERS THINK",
# 		    	userProfileShort: 'in size {size}',
# 		    	commentTitle: 'COMMENT',
# 		    	commentText: 'What do you think? People talk about quality, look and feel.',
# 		    	basedText: "Based on",
# 		    	customerReviews: "customer reviews",
# 		    	basedOnCustomerReviews: "[basedOnCustomerReviews]",
# 		    	boughtLabel: "Bought:",
# 		    	inSizeLabel: "in size",
# 		    	aboutMeLabel: "About me:",
# 		    	showMoreLabel: "Show more",
# 		    	selectedBodyType: "{bodyType} body type",
# 		    	selectedSkinTone: "[skynTone]",
# 		    	selectedSkinType: "{skinType} skin type",
# 		    	filterLabel: "[filter]",
# 		    	sortByLabel: "Sort by",
# 		    	sortOptionLables: [
# 		    		"Most Relevant",
# 		    		"Newest",
# 		    		"Highest Rated",
# 		    		"Lowest Rated"
# 		    	],
# 		    	reviewsDescriptionLabel: "[reviewDescription]",
# 		    	clearAllCta: "[clearAll]",
# 		    	noReviewesHeading: "[noMatchReview]",
# 		    	noReviewesText: "[noReviewText]",
# 		    	colorPurchased: "[purchasedColor]",
# 		    	sizePurchased: "[pushasedSize]",
# 		    	heightLabel: "Height",
# 		    	bodyTypeLabel: "[bodyTypeLabel]",
# 		    	skinToneLabel: "[skinToneLabel]",
# 		    	SkinTypeLabel: "[skinTypeLabel]",
# 		    	labelAll: "All",
# 		    	doneCta: "[done]",
# 		    	clearCta: "[clear]",
# 		    	backCta: "Back",
# 		    	unreviewedItemsPlaceholder: "Your purchased items will show up here, waiting for your review.",
# 		    	unreviewedItemsText: "Let&#039;s leave a review!",
# 		    	itmesCount: "{x} items",
# 		    	leaveReviewCta: "Leave a Review",
# 		    	gotohm: "Go to HM.com",
# 		    	reviewHeading: "REVIEW",
# 		    	shareThoughtsHeading: "SHARE YOUR THOUGHTS ON THIS ITEM!",
# 		    	dimensionText: "What do you think? People talk  about style, occasion and feel.",
# 		    	ratingValidationText: "Your review must include a rating.",
# 		    	maxLengthValidationText: "We&#039;d love to hear your full review, but we&#039;re limited to 5000 characters. Please shorten to post!",
# 		    	unfinishedReviewHeading: "Your review means a lot.",
# 		    	unfinishedReviewtext: "Please finish before you leave. Your changes will not be saved.",
# 		    	unfinishedReviewCta: "Yes, I want to finish",
# 		    	unfinishedReviewExit: "EXIT",
# 		    	shopNowLabel: "SHOP NOW",
# 		    	ratingStarTips: [
# 			    	'Poor',
# 			    	'Fair',
# 			    	'Average',
# 			    	'Good',
# 			    	'Excellent'
# 			    ],
# 			    myhmReviewSection: {
# 		    		noReviewText: 'Your purchased items will show up here, waiting for your review.',
# 				    canReviewText: 'You have {xx} item(s) waiting for your opinion.',
# 					errorText: 'Server error, please try again later.'
# 	        	},
# 			    headlines: {
# 			    	normal: {
# 			    	  title: "REVIEWS",
# 			    	  subTitle: "Tell us what you thought of these items"
# 			    	  },
# 			    	validationError: {
# 			    	  title: "ALMOST THERE!",
# 			    	  subTitle: "Please take a look at what is missing to continue:",
# 			    	  text:  "1. Add rating. 2. Tick Terms of Use box."
# 			    	},
# 			    	connectionError: {
# 			    	  title: "OH, SNAP!",
# 			    	  subTitle: "It looks like you can&#039;t review right now. Please try again later. Thanks for your patience!",
# 			    	  text:  "In the meanwile, head over to our shop!"
# 			    	},
# 			    	NotLoggedIn: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	  text:  ""
# 			    	},
# 			    	reviewFiltersError: {
# 			    	  title: "Sorry",
# 			    	  text: "We could not show any comments about this item at the moment. Please try again in a little while."
# 			    	},
# 			    	oldPurchasedProduct: {
# 			    	  title: "Sorry",
# 			    	  subTitle: "Products were purchased more than {x} days ago and cannot be reviewed.",
# 			    	  text: "However, you can still review below other items that you have bought."
# 			    	},
# 			    	reviewError: {
# 			    	  title: "HI AGAIN!",
# 			    	  subTitle: "YOU HAVE ALREADY REVIEWED THIS ITEM.",
# 			    	  text1: "However, you can still review other items that you have bought below.",
# 			    	  text2: "However, you can always head over to our shop to see what&#039;s trending right now!"
# 			    	},
# 			    	start: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	},
# 			    	end: {
# 			    	  title: "YOU&#039;RE THE BEST!",
# 			    	  subTitle: "Your reviews are very valuable",
# 			    	},
# 			    	random: [
# 			    	  "THE MORE THE BETTER!",
# 			    	  "JUST ONE MORE!",
# 			    	  "YES, THIS IS AWESOME!",
# 			    	  "YOU&#039;RE ON A ROLL",
# 			    	  "FLAWLESS!",
# 			    	  "YOU RISE AND SHINE!",
# 			    	  "MORE IS ALWAYS MORE, THANK YOU!",
# 			    	  "DIAMONDS, YOU KEEP ON GIVING!",
# 			    	]
# 	    		},
# 	    		 pointsCommunication: {
# 	                 nonLoggedIn: {
# 	                     copy1: "If you are a member, your points will be awarded if and when your review is published.",
# 	                     copy2: "If you are a member, your points will be awarded if and when your review is published. Not a member yet?{URL} Join now!{/URL}",
# 	                     modalURL: 'join'
# 	                 },
# 	                 clubMember: {
# 	                     copy1: "You&#039;ll earn 0 Points for each item you review — up to 0 products per month.",
# 	                     copy2: "Your points will be awarded if and when your review is published.",
# 	                     copy3: "You&#039;ll earn points for every review!",
# 	                     copy4: "Your points will be awarded if and when your review is published."
# 	                 },
# 	                 nonClubMember: {
# 	                     copy1: "If you {URL}become a member{/URL}, you can earn points when you review an item — collect enough points and you&#039;ll receive a bonus to use for future purchases.",
# 	                     copy2: "Don&#039;t forget to {URL}become a Loyalty Member{/URL} — you can earn points for leaving reviews! Collect enough points and you&#039;ll receive a reward to use on future purchases!",
# 	                     copy3: "Did you know Members earn points for product reviews and get exclusive offers and rewards? Join now, it’s free!",
# 	                     copy4: "Become a member",
# 	                     modalURL: 'club-upgrade'
# 	                 }
# 	             },
# 		    	continueShoppingBtn: {
# 			    	text: "Continue Shopping",
#                     urlLink: "/en_us/index.html"
# 			    },
# 			    joinClubBtn: {
# 			        text: "Become a member",
# 			        remodalTriggerId: "club-upgrade"
# 			    },
#     		},
# 		    showMoreBtn: {
# 	        	text: "Show More Products"
# 	      	}
#     	},
#     	notifyIfBack: {
#     		notifyMeButton: 'NOTIFY ME',
#     		notifyMeButton_text: 'Notify me',
#     		notifyMeList: 'Notify me',
#     		notifyMeListMessage: 'Get notified when your size is back.',
# 	        outOfStock: 'Out of stock',
# 	        moveToBag: '[moveToBag]',
# 	        modal: {
# 	          select: {
# 	            heading: 'KEEP ME POSTED',
# 	            info: 'If your product comes back in stock, we&#039;ll email you.',
# 	            pickSize: 'Size',
# 	            selectSize: 'Select size',
# 	            notify: 'WE WILL NOTIFY YOU AT:',
# 	            disclaimer: 'Your request will be saved for 3 months.',
# 	            button: 'NOTIFY ME',
# 	            heading_text: 'Keep me posted',
# 	            info_text: 'We&#039;ll let you know if the product comes back in stock.',
# 	            button_text: 'Notify me',
# 	            reminderFormTitle_text: 'Notify me by:',
# 	            emailMethodLabel_text: 'Email',
# 	            phoneMethodLabel_text: 'Text',
# 	            bothMethodLabel_text: 'Email and text',
# 	            emailLabel_text: 'Email*',
# 	            phoneLabel_text: 'Phone*',
# 	            invalidPhoneNumber_text: 'Invalid phone number',
# 	            invalidEmailAddress_text: 'Invalid email address',
# 	            warningInfo_text: '{0}',
# 	            warningInfoPhone_text: '*Your phone number will only be used to contact you about the product you requested. Standard carrier rates apply. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.',
# 	            warningInfoEmail_text: '*Your email will only be used to contact you about the product you requested. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.',
# 	            warningInfoFull_text: '*Your phone number and email will only be used to contact you about the product you requested. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.'
# 	          },
# 	          success: {
# 	            heading: 'YOU&#039;RE ALL SET',
# 	            info: 'If your product comes back in stock, we&#039;ll email you at {0}',
# 	            button: 'Continue Shopping',
# 	            heading_text: 'We&#039;ll notify you via the email or phone number below if your size comes back in stock:'
# 	          },
# 	          error: {
# 	            heading: 'OH NO!',
# 	            info: 'For some reason, we couldn&#039;t register your notification request.',
# 	            button: 'TRY AGAIN'
# 	          },
# 	          login: {
# 	            heading: 'DON&#039;T MISS OUT!',
# 	            info: 'Get notified if your product comes back in stock — it&#039;s easy!',
# 	            text: 'Simply sign in and click on &#039;Notify Me&#039; and you&#039;ll receive a notification if this product comes back again.',
# 	            button: 'Sign in / join'
# 	          }
# 	        }
# 	      },
# 		video: {
# 			'playButtonText' : 'Play video',
# 			'pauseButtonText' : 'Pause video',
# 			'closeButtonText' : 'Close video',
# 			'videoErrorTitle' : 'Oops!',
# 			'videoErrorText' : 'Seems like we&#039;re having trouble loading this video',
# 			'videoReloadText' : 'Reload',
# 			'videoLoadingText' : 'Video player is loading now'
# 		},
#     	searchImgAlt: {
# 	    	washTag: 'Wash Tag',
# 	    	priceTag: 'Price Tag'
#     	},
#     	confirm: 'OK',
# 	    general: {
# 	    	next: 'Next',
# 	    	previous: 'Previous',
# 	    	close: 'Close',
# 	    	all: 'All',
# 	    	enableContrastMode: 'Enable high-contrast mode',
# 	    	disableContrastMode: 'Disable high-contrast mode',
# 	    	hm: 'H&amp;M',
# 	    	hennes: 'Hennes &amp; Mauritz'
#     	},
#     	pdp: {
# 	    	artNo: 'Art. No.',
# 	    	soldOut: 'Sold out',
# 	    	fewPiecesLeft: 'Few pieces left',
# 	    	comingSoon: 'Coming soon',
# 	    	comingSoonButton: 'COMING SOON'
#     	},
#     	product: {
#     		newArrivalText: 'New Arrival'
#     	},
#     	completeRegistration: '[pleaseCompleteRegistration]',
#         giftCard: {
#         	servicedown: 'Service Down'
#         },
#         sustainability: {
#             starterButton: 'PRODUCT BACKGROUND',
#             modalTitle: 'PRODUCT BACKGROUND',
#             introText: 'We believe that greater transparency will help lead the change towards a more sustainable future. As a step in this long-term commitment, we’re sharing how and where our products are made wherever possible. ',
#             introTextNoSuppliers: 'We believe that greater transparency will help lead the change towards a more sustainable fashion future. As a first step in this long-term commitment, we’re sharing how our products are made wherever possible.',
#             materials: {
#               headerText: 'MATERIALS',
#               bodyText: 'Our goal is to use 100% recycled or other sustainably sourced materials by 2030.'
#             },
#             suppliers: {
#               headerText: 'OUR SUPPLIERS',
#               backText: "Back",
#               bodyTextCountryList: 'This product has been produced in one of the following countries:',
#               buttonSeeAllText: 'Suppliers and factories for this product.',
#               introText: 'All of our products are made by independent suppliers, often in developing countries where our presence can make a real difference. Our business helps to create jobs and independence, particularly for women — consequently lifting people out of poverty and contributing to economic growth.   We only work with partners who share our respect for people and the environment, and who are willing to work with us to improve their practices. All suppliers and factories must sign our strict Sustainability Commitment, which includes requirements for fair wages and good working conditions for all. We employ a dedicated sustainability staff in our worldwide production offices to make sure the commitment is followed.',
#               sorryText: 'Unfortunately, supplier and factory information isn’t currently available for this product. Thank you for being patient while we work towards displaying these details for all H&amp;M items possible.',
#               modalTitle: 'SUPPPLIER &amp; FACTORY LIST',
#               workersAmount: 'Number of workers:',
#               disclaimerTop: 'These suppliers and factories made this product for H&amp;M globally, which means that the item you will receive is produced by one of these suppliers and one of their factories.',
#               disclaimerLabelsupplierAndFactoryExplanationText: 'We want to be completely transparent with you about how and where our products are made, therefore we have a new system for this.',
#               disclaimerLabelsupplierAndFactoryExplanationText_2: 'However, if an item was produced before we started using our new system, all of the supplier information may not be available. We’re focusing our efforts on making sure all items going forward, display all supplier details.',
#               disclaimerLabelsupplierAndFactoryExplanationText_3: 'If we stop working with a supplier or factory, we’ll only display the last information that we had at the point of collaboration.',
#               disclaimerLabelsupplierAndFactoryExplanationText_4: 'Thank you for bearing with us while we work towards greater transparency.'
#             },
#             fashionRecycler: {
#               headerText: 'BE A FASHION RECYCLER!',
#               bodyText: 'You too can help the environment and make fashion more sustainable. Bring unwanted clothes or home textiles to any H&amp;M store and they will be reworn, reused or recycled.'
#             }
#           },
#         strength: {
#         	bad: 'Weak',
#        		medium: 'Good',
#         	strong: 'Strong'
#         }
#    	};
#     hm.options.passwordStrengthScript = {
#     		enabled: true,
#             urlPath: 'https://cdnjs.cloudflare.com/ajax/libs/zxcvbn/4.2.0/zxcvbn.js'
# 	};
#  hm.options.vkAppId = '5104831';
#  hm.options.baiduKey = 'swDgGnUXEsDc69fssH1PiFdMy0pqsq4y';
#  hm.options.rimd = {
# 		service: 'https://lp2.hm.com/hmgoepprod?set=width[{width}],quality[{quality}],options[limit]&source=url[{path}]&scale=width[global.width],height[15000],options[global.options]&sink=format[{ext}],quality[global.quality]',
# 		product: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&scale=width[{width}],height[{height}],options[{scale}]&sink=format[jpeg],quality[{quality}]&hmver={version}',
# 		serviceOverride: {
# 			gif: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&optimize&sink=format[{ext}]'
# 		}
# 	};
#  hm.options.googleMapApiKey = 'gme-hmhennesmauritzab';
#
#  hm.options.searchNumGuide = {
#  	    washTagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-wash.svg',
#  	    pricetagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-price.svg'
#  };
#
#  hm.options.turnTo = {
# 		  enabled: true,
#  	      dateFrom: '56',
#  	      ugcSummary: '/en_us/reviews/rrs/ugcsummary',
# 		  unreviewedPurchases: '/en_us/reviews/rrs/unreviewed',
# 	      reviewList: '/en_us/reviews/rrs/reviews',
# 	      createReview: '/en_us/reviews/rrs/createreview',
# 	      reviewFormSubmission: '/en_us/reviews/rrs/formsubmission',
#
#  	      	dimensionId: 1,
#
#  	      legal: [
#             {
#             	label: 'I accept {URL1}terms and conditions{/URL}',
#                 url1: '/en_us/customer-service/legal-and-privacy/reviews-terms-and-conditions.modal.html',
#              	validationText: "Please accept the terms and conditions to continue.",
#             	finePrint: 'The information you provide will be handled in accordance with our {URL2}Privacy notice{/URL}',
#                 url2: '/en_us/customer-service/legal-and-privacy/privacy-link.modal.html'
#             }
#  	      ]
#  	  };
#
# hm.options.notifyIfBack = {
# 	version : 'v1',
# 	enabled : true,
# 	email : true,
# 	sms : true,
# 	apiUrl: 'https://nib.hm.com/api/Notify'
# };
#
# hm.options.hideUnavailableSizes = false;
#
# hm.options.video = {
# 	'accountId' : '5985631876001',
# 	'playerId' : 'aKLjzHnEl'
# };
#
# hm.options.sizeSelectorMessage = {
# 	'sizeSelectorMessageFlag': 'true',
# 	'sizeScaleCodes': '270~271~272~277~278~281',
# 	'sizeSelectorMessage': 'We’ve removed half sizes in shoes. Please see our Size Guide for updates.~We’ve removed half sizes in shoes. Please see our Size Guide for updates.~We’ve removed half sizes in shoes. Please see our Size Guide for updates.~We’ve recently updated our kids’ shoe sizing. You may receive shoes with a different size than what you ordered, but the shoes measure the same length. Please see the Size Guide for updated measurements.~We’ve recently updated our kids’ shoe sizing. You may receive shoes with a different size than what you ordered, but the shoes measure the same length. Please see the Size Guide for updated measurements.~We’ve recently updated our kids’ shoe sizing. You may receive shoes with a different size than what you ordered, but the shoes measure the same length. Please see the Size Guide for updated measurements.'
# };
#
# hm.options.sizeGuideTooltipMessage = {
# 	'sizeGuideTooltipFlag': 'false',
# 	'sizeGuideTooltipMessage': ''
# };
#
#  hm.options.trendingSearches = {
#     url: '/en_us/pra/panel/top-searches',
#     errorTitle: '[trendingErrorTitle]'
#   };
#
#  hm.options.ugc = {enabled: true};
#
#  hm.options.isPublishMode = true;
#
#
#  hm.options.preshopperData = {
# 	bookingsService: '/en_us/loyalty/booking/bookings',
# 	memberService: '/en_us/loyalty/getMember',
# 	offersService: ''
#  };
#
#  hm.options.useNewFilter = true;
#
#  hm.options.quickBuyBaseUrl = '/en_us/productpage/_jcr_content/product.quickbuy.{{=it.articleCode}}.html';
#
#  hm.options.acceptableJoin = {};
#
#  	hm.options.acceptableJoin.popupTimes = 2;
#
#
#  hm.options.comparativePrice = true;
#
#  hm.options.sustainability = {
#          getSuppliers: '/en_us/supplierDetails/articles/'
#      }
#
#
#  $(document).ready(function(){
# 	 if(!hm.options.isPublishMode){
# 		 $('.preshopping-container').show();
# 	 }
# 	 else{
#  		$('.preshopping-container').has("article[data-preshopping-teaser=false]").show();
# 	 }
#  });
# </script><noscript>
# <div class="responsive status-message is-open notice">
# <div class="message icon icon-banner-info-white">
#   		Welcome! HM.com works best with JavaScript enabled. Turn it on and enjoy the latest fashion!
#   		</div>
# </div>
# </noscript><div class="warehousemessage"></div>
# <header class="header-global">
# <nav class="menu" ng-init="preshoppingOfferKey='';preshoppingCountdown='900000';preshoppingOfferPageUrl='';hmClubEnabled=true; timeInterval=5000; autorefreshCount=3;  offersSpace='rewardSpace'; hmClubServiceCacheDuration=0; hmRedirectPath='/en_us/account'">
# <a class="hide-content focusable" href="#main-content" title="Skip navigation">Skip navigation</a>
# <a class="menu__hm" href="/en_us/index.html">
# <span class="hide-content notranslate">HM.com</span>
# </a>
# <button class="menu__trigger js-menu-trigger">Menu</button>
# <ul class="menu__session menu__session--hidden">
# <li class="menu__session__item">
# <div class="account parbase">
# <a class="menu__myhm" data-remodal-trigger="signin" data-signin-state="guest" href="#">
# 		Sign in
# 	</a>
# <a class="menu__myhm" data-signin-state="signedin" href="/en_us/account">
# 		My Account
# 	</a>
# <div class="myhm-dropmenu" data-signin-state="guest">
# <button class="button large" data-remodal-trigger="signin">
#             Sign in
#          </button>
# <ul class="list">
# <li class="list-item">
# <a class="link" data-remodal-trigger="signin-account" href="/en_us/account">My Account</a>
# </li>
# <li class="list-item">
# <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
# </li>
# <li class="list-item">
# <a class="link" data-remodal-trigger="join" href="#">Not a Member yet? Join here!</a>
# </li>
# </ul>
# </div>
# <div class="myhm-dropmenu" data-signin-state="signedin">
# <ul class="list">
# <li class="list-item">
# <a class="link" href="/en_us/account">My Account</a>
# </li>
# ...
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy.html">Legal &amp; Privacy</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/contact.html">Contact</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/gift-card.html">Gift Card</a></div>
# <div class="item"><a class="link" href="https://www.hm.com/us/customer-service/ca-supply-chains-act">CA Supply Chains Act</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy/california-privacy-rights.html">California, Colorado, and Virginia Privacy Rights</a></div>
# <div class="item"><a class="link" href="/en_us/customer-service/legal-and-privacy/do-not-sell-ca.html">Do Not Sell My Personal Information</a></div>
# <button class="ot-sdk-show-settings link" id="ot-sdk-btn">Cookie Settings</button>
# </div>
# </nav>
# <section class="footer-newsletter">
# <div class="newsletter newslettersignupform parbase"><h4 class="footer-heading">Become a member</h4>
# <p class="text">Join now and get 10% off your next purchase!</p>
# <a class="button" href="/en_us/member/info.html">READ MORE</a></div>
# </section>
# </div>
# <ul class="footer-social footer-content">
# <li class="item">
# <a class="hidden-text icon icon-social-facebook-white" href="https://www.facebook.com/hmtheus" rel="noopener noreferrer" target="_blank" title="Facebook">
# 			Facebook</a></li>
# <li class="item">
# <a class="hidden-text icon icon-social-twitter-white" href="https://twitter.com/hmusa" rel="noopener noreferrer" target="_blank" title="Twitter">
# 			Twitter</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-instagram-white" href="https://www.instagram.com/hm/" rel="noopener noreferrer" target="_blank" title="Instagram">
# 			Instagram</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-youtube-white" href="http://www.youtube.com/user/hennesandmauritz" rel="noopener noreferrer" target="_blank" title="Youtube">
# 			Youtube</a>
# </li>
# <li class="item">
# <a class="hidden-text icon icon-social-pinterest-white" href="https://www.pinterest.com/hm/" rel="noopener noreferrer" target="_blank" title="Pinterest">
# 				Pinterest</a>
# </li>
# </ul>
# <div class="footer-copyright footer-content">
# <p class="text js-footer-truncate">
# 			The content of this site is copyright-protected and is the property of H&amp;M Hennes &amp; Mauritz AB. H&amp;M is committed to accessibility. That commitment means H&amp;M embraces WCAG guidelines and supports assistive technologies such as screen readers.  If you are using a screen reader, magnifier, or other assistive technologies and are experiencing difficulties using this website, please call our TOLL-FREE support line (855-466-7467) for assistance. H&amp;M's business concept is to offer fashion and quality at the best price. H&amp;M has since it was founded in 1947 grown into one of the world's leading fashion companies.</p>
# <button aria-hidden="false" class="js-footer-more link" data-read-less-label="READ  LESS">READ MORE</button>
# </div>
# <a class="footer-logotype icon icon-hm-white hidden-text" href="/en_us/index.html">H&amp;M</a>
# <div class="country-info"><div class="countrylanguage parbase"><a class="country-name overlay-trigger" data-layout="confirm" data-modal-scrollup="false" href="/en_us/_jcr_content/footer/locationlanguage.changelocation.html">United States</a> | $</div>
# </div>
# <div data-remodal-content-id="signin" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/loginform.modal.html, additionalClasses: club-modal-forms">
# </div>
# <div data-remodal-content-id="signin-account" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/loginform.modal.account.html, additionalClasses: club-modal-forms">
# </div>
# <div data-remodal-content-id="join" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/joinusform.modal.html, additionalClasses: club-modal-forms, closeAllButton: true">
# </div>
# <div class="remodal-content-wrapper" data-remodal-content-id="club-upgrade" data-remodal-options="popup: true, hashtracking: true, additionalClasses: club-modal-forms club-upgrade-form, closeAllButton: true">
# <button class="remodal-close" data-remodal-action="closeall">Close Dialog</button>
# <div class="remodal-content">
# <div class="hm-form">
# <header class="header">
# <h2 class="heading icon-hm-club-logo-light">Become a member</h2>
# <p class="excerpt">Become a Member — you'll enjoy exclusive deals, offers, invites and rewards.</p>
# </header>
# <form class="form js-form-clubjoin" method="POST" novalidate="">
# <div class="content">
# <div class="inputwrapper required">
# <div class="inputwrapper required">
# <label class="label" data-optional="(Optional)" for="club-dob">Date of birth</label>
# <div class="select-date">
# <div class="merged-inputs">
# <input autocomplete="bday-month" class="input-month text-input" id="club-signin-month" inputmode="numeric" maxlength="2" name="month" pattern="[0-9]*" placeholder="MM" size="2" type="tel"/>
# <span class="divider">/</span>
# <input autocomplete="bday-day" class="input-day text-input" id="club-signin-day" inputmode="numeric" maxlength="2" name="day" pattern="[0-9]*" placeholder="DD" size="2" type="tel"/>
# <span class="divider">/</span>
# <input autocomplete="bday-year" class="input-year text-input" id="club-signin-year" inputmode="numeric" maxlength="4" name="year" pattern="[0-9]*" placeholder="YYYY" size="4" type="tel"/>
# </div>
# <input class="input-date" data-format-text="Incorrect format" data-min-age="16" data-min-age-text="You have to be at least {0} years old to become a member" data-show-text-after-this="true" data-validation-birthdate="true" data-validation-minlength-text="Please enter your year of birth in a four digit format" data-validation-required-text="You have to enter a valid birthdate" id="club-dob" name="birthDate" required="" type="hidden" value=""/>
# </div>
# <div class="input-info">H&amp;M wants to give you a special treat on your birthday</div>
# </div>
# <div class="inputwrapper full">
# <input class="checkbox-input" name="hmClubJoin" type="hidden" value="true"/>
# <input class="checkbox-input" id="upgrade-create-account-fashion-news" name="hmNewsSubscription" type="checkbox" value="true"/>
# <label class="checkbox-label" for="upgrade-create-account-fashion-news">
#                             Yes, email me my member rewards, special invites, trend alerts and more.
#                         </label>
# <p class="checkbox-description">Your inbox is about to get a lot more stylish! Get excited for exclusive deals, trend alerts, first access to our new collections, and more. Plus, don't miss out on all your Member rewards, birthday offer and special invites to events!</p>
# </div>
# <p class="text">By clicking ‘Become a member’, I agree to the H&amp;M Membership <a class="underline" data-remodal-trigger="terms-and-conditions">Terms and conditions</a>.</p>
# <p class="text">To give you the full membership experience, we will process your personal data in accordance with the H&amp;M's <a class="underline" data-remodal-trigger="privacy-notice" href="/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.html">Privacy Notice</a>.</p>
# <button class="button large js-submit-clubjoin" type="submit">Become a member</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="remodal-content-wrapper" data-remodal-content-id="terms-and-conditions-for-club" data-remodal-options="escape:false, popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/clubtermsandconditions.modal.html, additionalClasses: popup-logo-header, closeButton: false">
# </div>
# <div class="globalmodals parbase">
# <div data-remodal-content-id="terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="termsconditions-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacypolicy-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-notice" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-policy" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-link.modal.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-privacy">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-direct-marketing" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-direct-marketing-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# <div class="remodal-content"></div>
# </div>
# <div data-remodal-content-id="privacy-policy-fashion" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-account-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/dataprocessing.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-overseastransfer" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/overseastransfer.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-thirdpartytransfer" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/third-party-transfer.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-info-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/data-usage-info.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="marketing-information-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/marketing-and-receive-advertising-information.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="hmclub-terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/h-m-club/h-m-club-terms-conditions.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <!-- Modal content for the account access   -->
# <div data-remodal-content-id="accountaccess-popup" data-remodal-options="ajaxUrl:/en_us/customer-service/dontagreepage.modal.html, popup: true, additionalClasses: account-access">
# <header class="remodal-header">
# <h2 class="heading">
# </h2>
# </header>
# <div class="remodal-content"></div>
# </div>
# </div>
# </div></footer><!-- /Footer -->
# <div class="tealiumPageviewtag pageview parbase"><script type="text/javascript">utag_data = {touchpoint : getTouchpoint() , page_id : "Men : Shopbyproduct : Jeans : Viewall", category_id : "MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL", category_path : "MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL", selected_market : "US", display_language : "en_US", event_type  : "", customer_id : "", customer_email : "", customer_zip : "", customer_city : "", customer_state : "", customer_state : "", customer_country : "", customer_loyalty_level : "", customer_has_children : "", customer_fashion_news : "" }; utagTealiumTrack(function(a,b,c,d){var forceUtagLogic = (hm.device.iPhone() && hm.options.forceUtagForIOS) || (hm.device.android() && hm.options.forceUtagForAndroid);    if(!hm.device.app() || (hm.device.app() && forceUtagLogic ) ){a=getTealiumURL("US");b=document;c='script';d=b.createElement(c);d.src=a;d.id='utagMainScript';d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);}}); hm.Tracking.appPageView(utag_data);</script> </div>
# <div class="nuancechat nuanceChat parbase">
# <div id="Nuance-chat-anchored"></div>
# <script async="" charset="utf-8" src="https://hm-us.inq.com/chatskins/launch/inqChatLaunch10006533.js" type="text/javascript"></script>
# <script>
# 	  hm.waitUntil(function() {
# 			return hm.version;
# 		}).then(function() {
# 			hm.cookies = hm.cookies || new hm.Cookies();
# 			var nuanceData={};
# 			window.nuanceData = nuanceData;
# 			if(hm.cookies && hm.cookies.readCookie('userCookie')){
# 				var userCookieVal = JSON.parse(hm.cookies.readCookie('userCookie'));
# 				if (userCookieVal){
#
# 					if(userCookieVal.cartCount>=0){
# 						nuanceData["cartCount"] = userCookieVal.cartCount;
# 					}
# 				if(userCookieVal.dominantCategory){
# 						nuanceData["dominantCategory"] = userCookieVal.dominantCategory;
# 					}
# 					if(userCookieVal.cartProducts){
# 						nuanceData["cartProducts"] = userCookieVal.cartProducts;
# 					}
# 					if(userCookieVal.hybris_firstName){
# 						nuanceData["hybris_firstName"] = decodeURIComponent((userCookieVal.hybris_firstName + '').replace(/\+/g, '%20'));
# 					}
# 					if(userCookieVal.hybris_uuid){
# 						nuanceData["hybris_uuid"] = userCookieVal.hybris_uuid;
# 					}
# 					if(userCookieVal.customer_id){
# 						nuanceData["customer_id"] = userCookieVal.customer_id;
# 					}
# 					if(userCookieVal.type){
# 						nuanceData["type"] = userCookieVal.type;
# 					}
# 					if(userCookieVal.str){
# 						nuanceData["st"] = decodeURIComponent(userCookieVal.str.replaceAll(/\+/g, ' '));
# 					}
# 					if(userCookieVal.zc){
# 						var val = userCookieVal.zc.replace(/[+,-]/g," ");
# 							nuanceData["zc"] = val;
# 				}
# 					if(userCookieVal.tn){
# 						nuanceData["tn"] = decodeURIComponent(userCookieVal.tn.replaceAll(/\+/g, ' '));
# 					}
# 				}
# 			}
# 			var favouritesCookie = hm.options.product.country + "-favourites";
#
# 			var hasFav = hm.cookies.readCookie("hm-austria-favourites");
# 			if(hasFav && !(hasFav==="\"\"")){nuanceData["hm-country-favourites"] = hasFav;}
# 			console.log(nuanceData);
# 		});
# 		</script>
# <script type="text/javascript">
# 			// Click on Chat icon
# 			$(document).on("click", "#Nuance-chat-anchored", function() {
# 				hm.Tracking.link({
# 					event_type : 'AI_CHAT_INITIATE',
# 					event_id : 'Click on Start AI chat',
# 					event_category : 'AI Chat',
# 					event_label : hm.options.tealiumPageId
# 				});
#
# 				console.log(document.URL);
# 			});
# 		</script>
# </div>
# </div>
# <script src="/B2hlry7V/Geuh4Bm/V75v13g/WC/EObiSbmz/XiljaAMMfAM/UggoL/A8GUGA" type="text/javascript"></script></body></html>

# %%
# Paginação: Retornando todas as páginas do site

soup.find_all('h2', class_='load-more-heading')
# Out:
# [<h2 class="load-more-heading" data-items-shown="36" data-total="87">SHOWING 36 of 87 Items</h2>]

# %%
# Retornando todos os produtos de todas as páginas do site

total_item = soup.find_all('h2', class_='load-more-heading')[0].get('data-total')
total_item
# Out:
# '87'

# %%
# Transformando em inteiro para saber quantas páginas presciso
# Cabem 36 produtos por páginas, com isso presciso de 2.41 páginas

int(total_item)/36
# Out:
# 2.4166666666666665

# %%
# Arredondando os valores

#page_number = np.round(int(total_item)/36)
#page_number

# %%
# Arredondando os valores para saber quantas páginas preciso

page_number = math.ceil(int(total_item)/36)
page_number
# Out:
# 3

# %%
url02 = url1 + '?pagesize=' + str(int(page_number*36))
url02
# Out:
# 'https://www2.hm.com/en_us/men/products/jeans.html?pagesize=108'

# %%
# Estrutura HTML onde a vitrine está armazenada:

products = soup.find('ul', class_ = 'products-listing small')

# %%
products
# Out:
# <ul class="products-listing small">
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1074475001" data-brand="H&amp;M" data-category="men_jeans_loose" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1074475001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTA3NDQ3NV9ncm91cF8wMDFfZW5fdXM7MTA3NDQ3NTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1074475001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1074475001.html" title="Loose Jeans">
# <img alt="Loose JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e6/fe/e6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Loose Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/85/1f/851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/85/1f/851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1074475001|Loose Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1074475001.html">Loose Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="1">
# <li class="item"><a class="swatch" href="/en_us/productpage.1074475001.html" style="background-color: #D0D7E6" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1071707001" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1071707001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTA3MTcwN19ncm91cF8wMDFfZW5fdXM7MTA3MTcwNzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1071707001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1071707001.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f0/6b/f06baaff711d89d8ca7b2f79ca544762a4874a31.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1071707001|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1071707001.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="2">
# <li class="item"><a class="swatch" href="/en_us/productpage.1071707001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1071707002.html" style="background-color: #AFBBE0" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256001" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0690449056" data-brand="H&amp;M" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449056'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTZfZW5fdXM7MDY5MDQ0OTA1Nl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0690449056');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0690449056.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f4/72/f472300fb43decf6dcffaece4e2c3249073615e3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/fe/5a/fe5adbcf84640be35dbd81701d1e96a0d7a9a6cf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/fe/5a/fe5adbcf84640be35dbd81701d1e96a0d7a9a6cf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449056|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="4">
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
# 				Gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159001" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/c6/28c6fee2e6b364c8a9adafb534eb286135403daf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
# 				Dark denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008549006" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDZfZW5fdXM7MTAwODU0OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549006');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008549006.html" title="Regular Jeans">
# <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/35/ab/35ab68c1b85dddca60628313e019c1c2851e7a5f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6a/c6/6ac683cb814037acd445d336b6eddb5f4f7419e1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549006|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008549006.html">Regular Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549006.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
# 				Dark gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256005" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDVfZW5fdXM7MTAyNDI1NjAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256005');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256005.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5a/97/5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/b2/00/b200579316e1ac59f64c39032a865f7b82faa330.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256005|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256005.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
# 				Dark blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256003" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDNfZW5fdXM7MTAyNDI1NjAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256003.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e3/e8/e3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/19/87/19876165367c49d17f3b8a9f51402fde689f3576.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256002" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDJfZW5fdXM7MTAyNDI1NjAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256002.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/da/ba/dabaf3f73477f46b068e2e02033aa0222206ef7f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/17/f1/17f1bb91c09c459b1b0c6e0558576dc6b2f548c0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256002|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256002.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008549001" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDFfZW5fdXM7MTAwODU0OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008549001.html" title="Regular Jeans">
# <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/21/b6/21b6c31f8625aa461fc8341941909488e60a2b20.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f1/78/f178470ab26293a1a0b3a7cb0accd18a879144e3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549001|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008549001.html">Regular Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
# 				Dark gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549004.html" style="background-color: #687483" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199002" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDJfZW5fdXM7MTAwNDE5OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199002.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/95/fe/95fe0c8d937eed977512d685f7ab8b2d64464a6d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/e4/78/e478e17cf81d55c47a422ccefa05c411c928d9f4.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199002|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
# 				White</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256008" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDhfZW5fdXM7MTAyNDI1NjAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256008');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256008.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/90/1a/901a0264da9ef3fb0567c0516241a242e3a74352.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d5/06/d50632768cbfe18eb354098883b6bed12373dcf6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256008|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256008.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256008.html" style="background-color: #FFFFFF" title="White">
# 				White</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159008" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDhfZW5fdXM7MDk4NTE1OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159008');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159008.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/86/f7/86f7b1e25d225723055ab84afd366dd7258165ce.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d2/1b/d21b76a3f85303a877a8fc8f0a9a26dd657ecc63.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159008|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159008.html" style="background-color: #494A4F" title="Dark gray">
# 				Dark gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199004" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDRfZW5fdXM7MTAwNDE5OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199004');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199004.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/23/ce237bac8d72f49453501ff497b4d4a51128eb13.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/9a/34/9a340bcdc14bf3e8290cb46be23163cfc8c908b8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199004|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199004.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
# 				White</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159007" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDdfZW5fdXM7MDk4NTE1OTAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159007');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159007.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/7e/ce7e4bb772917a1ae43e8b8b9dc0bdb6afbf5d9d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/51/a8/51a81a075021df32fe1b4509ca011e7277598cfb.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159007|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159007.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159007.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256004" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDRfZW5fdXM7MTAyNDI1NjAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256004');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256004.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/79/34/7934a8d7525532547dfef00416aba449e58493d1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/04/ef/04ef0c4c3360d565b91e0d64647d8a4572191b88.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256004|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0875105018" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105018'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMThfZW5fdXM7MDg3NTEwNTAxOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0875105018');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0875105018.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5e/04/5e04f734c55492ebbc258149ebd849d0993b6bcd.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/b6/e9/b6e9ac05f78baabddd302538b44bcdb2a6d1bcc8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105018|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0875105018.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
# 				Pale denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199003" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDNfZW5fdXM7MTAwNDE5OTAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199003.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/cc/87/cc87a24cff9adf0c17a4c3a1122b51d85c466170.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/30/63/3063969a89c23f71bb602ff365af98c850a8cbd8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199003|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199003.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
# 				White</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008549003" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDNfZW5fdXM7MTAwODU0OTAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008549003.html" title="Regular Jeans">
# <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2e/43/2e436b3e9e9787919274c8fd3db1cc33b0640f47.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/17/7b/177b6aa7c192b02ed46b91445c13f7ab2163097b.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549003|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008549003.html">Regular Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
# 				Dark gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# ...
# 				Gray</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
# 				Black/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
# 				Light denim blue/trashed</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159006" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDZfZW5fdXM7MDk4NTE1OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159006');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159006.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/67/e2/67e212499202f0e54ca448a91bef261a414187ad.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/04/1f/041f48bf2d127728bbe2361907c84de6e4ef8eb6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159006|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159006.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159005" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDVfZW5fdXM7MDk4NTE1OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159005');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159005.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/1f/cc/1fcc801708d85fa6181473072380341c9c1bd219.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0b/6b/0b6b7a9dc7904561d604839e7cb63f541a37499c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159005|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
# 				Dark denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1013317010" data-brand="H&amp;M" data-category="men_jeans_joggers" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317010'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMTBfZW5fdXM7MTAxMzMxNzAxMF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1013317010');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1013317010.html" title="Hybrid Regular Tapered Joggers">
# <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/6e/50/6e50acd0ddb7c78870f2552d33fa4acddea41533.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/a1/5d/a15d9efefbf6d68c5c8a89899d2c42c0a5709c21.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317010|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1013317010.html">Hybrid Regular Tapered Joggers</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 39.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317010.html" style="background-color: #232327" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
# 				Dark gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0875105024" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105024'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMjRfZW5fdXM7MDg3NTEwNTAyNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0875105024');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0875105024.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8b/6f/8b6f3e1f0ca6fbd57492d96b907b32e638455f3f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/1d/77/1d77f74382f9fc59966c015c083a1ad4e4a0081c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105024|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0875105024.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105024.html" style="background-color: #798DB2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
# 				Pale denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008549008" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDhfZW5fdXM7MTAwODU0OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549008');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008549008.html" title="Regular Jeans">
# <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/c7/7a/c77a6aee62aee1a847c5ad855820a37622b571fe.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/83/cd/83cd07b736e74efe5f325fcebcfc6a4b9ac729c1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549008|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008549008.html">Regular Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="7">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549008.html" style="background-color: #C4CAD7" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
# 				Dark gray</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1008110002" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDJfZW5fdXM7MTAwODExMDAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008110002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1008110002.html" title="Freefit® Slim Jeans">
# <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/90/22/90220f06a785e19d3d05abe6e6bf3c174b9b8f27.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0f/ec/0fec4ba3143c89684ca1f6be70ed6e86cf9ee631.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110002|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1008110002.html">Freefit® Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 49.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
# 				Black/No fade black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1008110005.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul></div></article></li>
# </ul>

# %%
# Estrutura HTML onde todos os produtos estão armazenados:
# Dados a serem coletados: data-articlecode, data-category

product_list = products.find_all('article', class_= 'hm-product-item')

# %%
product_list
# Out:
# [<article class="hm-product-item" data-articlecode="1074475001" data-brand="H&amp;M" data-category="men_jeans_loose" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1074475001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTA3NDQ3NV9ncm91cF8wMDFfZW5fdXM7MTA3NDQ3NTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1074475001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1074475001.html" title="Loose Jeans">
#  <img alt="Loose JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e6/fe/e6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Loose Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/85/1f/851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/85/1f/851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1074475001|Loose Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1074475001.html">Loose Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="1">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1074475001.html" style="background-color: #D0D7E6" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="1071707001" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1071707001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTA3MTcwN19ncm91cF8wMDFfZW5fdXM7MTA3MTcwNzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1071707001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1071707001.html" title="Relaxed Jeans">
#  <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f0/6b/f06baaff711d89d8ca7b2f79ca544762a4874a31.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1071707001|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1071707001.html">Relaxed Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="2">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1071707001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1071707002.html" style="background-color: #AFBBE0" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="1024256001" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0690449056" data-brand="H&amp;M" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449056'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wNTZfZW5fdXM7MDY5MDQ0OTA1Nl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0690449056');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449056.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f4/72/f472300fb43decf6dcffaece4e2c3249073615e3.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/fe/5a/fe5adbcf84640be35dbd81701d1e96a0d7a9a6cf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/fe/5a/fe5adbcf84640be35dbd81701d1e96a0d7a9a6cf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449056|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449051.html" style="background-color: #94989F" title="Gray">
#  				Gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159001" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/c6/28c6fee2e6b364c8a9adafb534eb286135403daf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008549006" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDZfZW5fdXM7MTAwODU0OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008549006.html" title="Regular Jeans">
#  <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/35/ab/35ab68c1b85dddca60628313e019c1c2851e7a5f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6a/c6/6ac683cb814037acd445d336b6eddb5f4f7419e1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549006|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008549006.html">Regular Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549006.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256005" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDVfZW5fdXM7MTAyNDI1NjAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256005');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256005.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5a/97/5a9787e31a37242c09b67d2f224bbd8b1c999c35.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/b2/00/b200579316e1ac59f64c39032a865f7b82faa330.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256005|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256005.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256005.html" style="background-color: #2F323B" title="Dark blue">
#  				Dark blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256003" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDNfZW5fdXM7MTAyNDI1NjAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256003.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e3/e8/e3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/19/87/19876165367c49d17f3b8a9f51402fde689f3576.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256002" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDJfZW5fdXM7MTAyNDI1NjAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256002.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/da/ba/dabaf3f73477f46b068e2e02033aa0222206ef7f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/17/f1/17f1bb91c09c459b1b0c6e0558576dc6b2f548c0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256002|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256002.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008549001" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDFfZW5fdXM7MTAwODU0OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008549001.html" title="Regular Jeans">
#  <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/21/b6/21b6c31f8625aa461fc8341941909488e60a2b20.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f1/78/f178470ab26293a1a0b3a7cb0accd18a879144e3.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549001|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008549001.html">Regular Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549004.html" style="background-color: #687483" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199002" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDJfZW5fdXM7MTAwNDE5OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199002.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/95/fe/95fe0c8d937eed977512d685f7ab8b2d64464a6d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/e4/78/e478e17cf81d55c47a422ccefa05c411c928d9f4.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199002|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256008" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDhfZW5fdXM7MTAyNDI1NjAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256008');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256008.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/90/1a/901a0264da9ef3fb0567c0516241a242e3a74352.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d5/06/d50632768cbfe18eb354098883b6bed12373dcf6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256008|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256008.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256008.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159008" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDhfZW5fdXM7MDk4NTE1OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159008');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159008.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/86/f7/86f7b1e25d225723055ab84afd366dd7258165ce.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/d2/1b/d21b76a3f85303a877a8fc8f0a9a26dd657ecc63.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159008|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159008.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199004" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDRfZW5fdXM7MTAwNDE5OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199004.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/23/ce237bac8d72f49453501ff497b4d4a51128eb13.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/9a/34/9a340bcdc14bf3e8290cb46be23163cfc8c908b8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199004|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199004.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159007" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDdfZW5fdXM7MDk4NTE1OTAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159007');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159007.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/7e/ce7e4bb772917a1ae43e8b8b9dc0bdb6afbf5d9d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/51/a8/51a81a075021df32fe1b4509ca011e7277598cfb.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159007|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159007.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159007.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1024256004" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDRfZW5fdXM7MTAyNDI1NjAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1024256004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1024256004.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/79/34/7934a8d7525532547dfef00416aba449e58493d1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/04/ef/04ef0c4c3360d565b91e0d64647d8a4572191b88.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256004|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0875105018" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105018'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMThfZW5fdXM7MDg3NTEwNTAxOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0875105018');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0875105018.html" title="Relaxed Jeans">
#  <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5e/04/5e04f734c55492ebbc258149ebd849d0993b6bcd.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/b6/e9/b6e9ac05f78baabddd302538b44bcdb2a6d1bcc8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105018|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0875105018.html">Relaxed Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105023.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199003" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDNfZW5fdXM7MTAwNDE5OTAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1004199003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199003.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/cc/87/cc87a24cff9adf0c17a4c3a1122b51d85c466170.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/30/63/3063969a89c23f71bb602ff365af98c850a8cbd8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199003|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199003.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008549003" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDNfZW5fdXM7MTAwODU0OTAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008549003.html" title="Regular Jeans">
#  <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2e/43/2e436b3e9e9787919274c8fd3db1cc33b0640f47.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/17/7b/177b6aa7c192b02ed46b91445c13f7ab2163097b.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549003|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008549003.html">Regular Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
# ...
#  				Gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449043.html" style="background-color: #79829D" title="Light denim blue/trashed">
#  				Light denim blue/trashed</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449056.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159006" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDZfZW5fdXM7MDk4NTE1OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159006.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/67/e2/67e212499202f0e54ca448a91bef261a414187ad.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/04/1f/041f48bf2d127728bbe2361907c84de6e4ef8eb6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159006|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159006.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159005" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDVfZW5fdXM7MDk4NTE1OTAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0985159005');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159005.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/1f/cc/1fcc801708d85fa6181473072380341c9c1bd219.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0b/6b/0b6b7a9dc7904561d604839e7cb63f541a37499c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159005|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
#  				Dark blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1013317010" data-brand="H&amp;M" data-category="men_jeans_joggers" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1013317010'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAxMzMxN19ncm91cF8wMTBfZW5fdXM7MTAxMzMxNzAxMF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1013317010');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1013317010.html" title="Hybrid Regular Tapered Joggers">
#  <img alt="Hybrid Regular Tapered JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/6e/50/6e50acd0ddb7c78870f2552d33fa4acddea41533.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Hybrid Regular Tapered Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/a1/5d/a15d9efefbf6d68c5c8a89899d2c42c0a5709c21.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1013317010|Hybrid Regular Tapered Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1013317010.html">Hybrid Regular Tapered Joggers</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317010.html" style="background-color: #232327" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1013317005.html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0875105024" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105024'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMjRfZW5fdXM7MDg3NTEwNTAyNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','0875105024');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0875105024.html" title="Relaxed Jeans">
#  <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8b/6f/8b6f3e1f0ca6fbd57492d96b907b32e638455f3f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/1d/77/1d77f74382f9fc59966c015c083a1ad4e4a0081c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105024|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0875105024.html">Relaxed Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105024.html" style="background-color: #798DB2" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008549008" data-brand="H&amp;M" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008549008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODU0OV9ncm91cF8wMDhfZW5fdXM7MTAwODU0OTAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008549008');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008549008.html" title="Regular Jeans">
#  <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/c7/7a/c77a6aee62aee1a847c5ad855820a37622b571fe.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/83/cd/83cd07b736e74efe5f325fcebcfc6a4b9ac729c1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008549008|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008549008.html">Regular Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549008.html" style="background-color: #C4CAD7" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549002.html" style="background-color: #7187BC" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008549003.html" style="background-color: #4D4D4B" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1008110002" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1008110002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwODExMF9ncm91cF8wMDJfZW5fdXM7MTAwODExMDAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1008110002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1008110002.html" title="Freefit® Slim Jeans">
#  <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/90/22/90220f06a785e19d3d05abe6e6bf3c174b9b8f27.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0f/ec/0fec4ba3143c89684ca1f6be70ed6e86cf9ee631.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1008110002|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious choice  </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1008110002.html">Freefit® Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 49.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110002.html" style="background-color: #272628" title="Black/No fade black">
#  				Black/No fade black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110001.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110003.html" style="background-color: #79829D" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1008110005.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>]

# %%
# Coleta primeiro elemento da lista

product_list[1]
# Out:
# <article class="hm-product-item" data-articlecode="1071707001" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1071707001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTA3MTcwN19ncm91cF8wMDFfZW5fdXM7MTA3MTcwNzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3OTs','1071707001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1071707001.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f0/6b/f06baaff711d89d8ca7b2f79ca544762a4874a31.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/2a/67/2a67a9b93adf8f0791b7b35fc1777d5ab3f20379.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1071707001|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1071707001.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="2">
# <li class="item"><a class="swatch" href="/en_us/productpage.1071707001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1071707002.html" style="background-color: #AFBBE0" title="Light denim blue">
# 				Light denim blue</a></li>
# </ul><div class="new-product">New Arrival</div>
# </div></article>

# %%
# Quantidade de artigos na lista

len(product_list)
# Out:
# 36

# %%
# Coleta primeiro item da lista de dados data-articlecode

product_list[0].get('data-articlecode')
# Out:
# '1074475001'

# %%
# Looping para coleta de todos os itens data-articlecode da lista 
# Product Id

product_id = [p.get('data-articlecode') for p in product_list]
product_id
# Out:
# ['1074475001',
#  '1071707001',
#  '1024256001',
#  '0690449056',
#  '0985159001',
#  '1008549006',
#  '1024256005',
#  '1024256003',
#  '1024256002',
#  '1008549001',
#  '1004199002',
#  '1024256008',
#  '0985159008',
#  '1004199004',
#  '0985159007',
#  '1024256004',
#  '0875105018',
#  '1004199003',
#  '1008549003',
#  '0811993036',
#  '0985159004',
#  '1024256007',
#  '1008110001',
#  '0690449022',
#  '0811993040',
#  '1004199001',
#  '0875105016',
#  '1008549002',
#  '0690449043',
#  '0690449051',
#  '0985159006',
#  '0985159005',
#  '1013317010',
#  '0875105024',
#  '1008549008',
#  '1008110002']

# %%
# Coleta primeiro item da lista de dados data-category

product_list[0].get('data-category')
# Out:
# 'men_jeans_loose'

# %%
# Looping para coleta de todos os itens data-category da lista 
# Product Type

product_type = [p.get('data-category') for p in product_list]
product_type
# Out:
# ['men_jeans_loose',
#  'men_jeans_relaxed',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_skinny',
#  'men_jeans_regular',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_regular',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_relaxed',
#  'men_jeans_skinny',
#  'men_jeans_regular',
#  'men_jeans_regular',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_regular',
#  'men_jeans_skinny',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_ripped',
#  'men_jeans_ripped',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_joggers',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_slim']

# %%
# Estrutura HTML onde todos nomes dos produtos estão armazenados:
# Dados aserem coletados: product_name

product_list = products.find_all('a', class_='link')
product_list
# Out:
# [<a class="link" href="/en_us/productpage.1074475001.html">Loose Jeans</a>,
#  <a class="link" href="/en_us/productpage.1071707001.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449056.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549006.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256005.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256003.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256002.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549001.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256008.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159008.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004199004.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159007.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256004.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0875105018.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004199003.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549003.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.0811993036.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159004.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1024256007.html">Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008110001.html">Freefit® Slim Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449022.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0811993040.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1004199001.html">Skinny Cropped Jeans</a>,
#  <a class="link" href="/en_us/productpage.0875105016.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549002.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449043.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0690449051.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159006.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.0985159005.html">Skinny Jeans</a>,
#  <a class="link" href="/en_us/productpage.1013317010.html">Hybrid Regular Tapered Joggers</a>,
#  <a class="link" href="/en_us/productpage.0875105024.html">Relaxed Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008549008.html">Regular Jeans</a>,
#  <a class="link" href="/en_us/productpage.1008110002.html">Freefit® Slim Jeans</a>]

# %%
# Coleta primeiro item da lista de dados product_name

product_list[0].get_text()
# Out:
# 'Loose Jeans'

# %%
# Looping para coleta de todos os itens product_name da lista 
# Product Name

product_name = [p.get_text() for p in product_list]
product_name
# Out:
# ['Loose Jeans',
#  'Relaxed Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Regular Jeans',
#  'Slim Jeans',
#  'Slim Jeans',
#  'Slim Jeans',
#  'Regular Jeans',
#  'Skinny Cropped Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Cropped Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Relaxed Jeans',
#  'Skinny Cropped Jeans',
#  'Regular Jeans',
#  'Regular Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Freefit® Slim Jeans',
#  'Skinny Jeans',
#  'Regular Jeans',
#  'Skinny Cropped Jeans',
#  'Relaxed Jeans',
#  'Regular Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Hybrid Regular Tapered Joggers',
#  'Relaxed Jeans',
#  'Regular Jeans',
#  'Freefit® Slim Jeans']

# %%
# Estrutura HTML onde o price está armazenado
# Dados aserem coletados: product_price

product_list = products.find_all('span', class_='price regular')
product_list
# Out:
# [<span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 49.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 39.99</span>,
#  <span class="price regular">$ 29.99</span>,
#  <span class="price regular">$ 19.99</span>,
#  <span class="price regular">$ 49.99</span>]

# %%
# Coleta primeiro item da lista de dados product_price

product_list[0].get_text()
# Out:
# '$ 39.99'

# %%
# Looping para coleta de todos os itens product_price da lista 
# Product Price

product_price = [p.get_text() for p in product_list]
product_price
# Out:
# ['$ 39.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 49.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 49.99']

# %%
pd.DataFrame([product_id,
              product_name,
              product_type,
              product_price,]).T
# Out:
#              0                               1                  2        3
# 0   1074475001                     Loose Jeans    men_jeans_loose  $ 39.99
# 1   1071707001                   Relaxed Jeans  men_jeans_relaxed  $ 29.99
# 2   1024256001                      Slim Jeans     men_jeans_slim  $ 19.99
# 3   0690449056                    Skinny Jeans   men_jeans_ripped  $ 39.99
# 4   0985159001                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 5   1008549006                   Regular Jeans  men_jeans_regular  $ 19.99
# 6   1024256005                      Slim Jeans     men_jeans_slim  $ 19.99
# 7   1024256003                      Slim Jeans     men_jeans_slim  $ 19.99
# 8   1024256002                      Slim Jeans     men_jeans_slim  $ 19.99
# 9   1008549001                   Regular Jeans  men_jeans_regular  $ 19.99
# 10  1004199002            Skinny Cropped Jeans   men_jeans_skinny  $ 29.99
# 11  1024256008                      Slim Jeans     men_jeans_slim  $ 19.99
# 12  0985159008                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 13  1004199004            Skinny Cropped Jeans   men_jeans_skinny  $ 29.99
# 14  0985159007                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 15  1024256004                      Slim Jeans     men_jeans_slim  $ 19.99
# 16  0875105018                   Relaxed Jeans  men_jeans_relaxed  $ 29.99
# 17  1004199003            Skinny Cropped Jeans   men_jeans_skinny  $ 29.99
# 18  1008549003                   Regular Jeans  men_jeans_regular  $ 19.99
# 19  0811993036                   Regular Jeans  men_jeans_regular  $ 29.99
# 20  0985159004                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 21  1024256007                      Slim Jeans     men_jeans_slim  $ 19.99
# 22  1008110001             Freefit® Slim Jeans     men_jeans_slim  $ 49.99
# 23  0690449022                    Skinny Jeans   men_jeans_ripped  $ 39.99
# 24  0811993040                   Regular Jeans  men_jeans_regular  $ 29.99
# 25  1004199001            Skinny Cropped Jeans   men_jeans_skinny  $ 29.99
# 26  0875105016                   Relaxed Jeans  men_jeans_relaxed  $ 29.99
# 27  1008549002                   Regular Jeans  men_jeans_regular  $ 19.99
# 28  0690449043                    Skinny Jeans   men_jeans_ripped  $ 39.99
# 29  0690449051                    Skinny Jeans   men_jeans_ripped  $ 39.99
# 30  0985159006                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 31  0985159005                    Skinny Jeans   men_jeans_skinny  $ 19.99
# 32  1013317010  Hybrid Regular Tapered Joggers  men_jeans_joggers  $ 39.99
# 33  0875105024                   Relaxed Jeans  men_jeans_relaxed  $ 29.99
# 34  1008549008                   Regular Jeans  men_jeans_regular  $ 19.99
# 35  1008110002             Freefit® Slim Jeans     men_jeans_slim  $ 49.99

# %%
data = pd.DataFrame([product_id,
              product_name,
              product_type,
              product_price,]).T

# %%
data.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data.columns = ['product_id',
                'product_name',
                'product_type',
                'product_price']

# %%
# scrapy datetime

data['scrapy_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data.head()
# Out:
#    product_id   product_name       product_type product_price  \
# 0  1074475001    Loose Jeans    men_jeans_loose       $ 39.99
# 1  1071707001  Relaxed Jeans  men_jeans_relaxed       $ 29.99
# 2  1024256001     Slim Jeans     men_jeans_slim       $ 19.99
# 3  0690449056   Skinny Jeans   men_jeans_ripped       $ 39.99
# 4  0985159001   Skinny Jeans   men_jeans_skinny       $ 19.99
#
#        scrapy_datetime
# 0  2022-05-31 14:09:35
# 1  2022-05-31 14:09:35
# 2  2022-05-31 14:09:35
# 3  2022-05-31 14:09:35
# 4  2022-05-31 14:09:35

# %%
# Retornando os detalhes de cada produto

# One product

url = 'https://www2.hm.com/en_us/productpage.1074475001.html'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get( url, headers=headers )

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="en-US" class="no-js en-us">\n    \n\n\n    <head>\r\n    \r\n  <link rel="dns-prefetch" href="https://s1-cdn.hm.com"/>\r\n  <link rel="preconnect" href="https://s1-cdn.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://tags.tiqcdn.com"/>\r\n  <link rel="preconnect" href="https://tags.tiqcdn.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://lp2.hm.com"/>\r\n  <link rel="preconnect" href="https://lp2.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://cdn-pci.optimizely.com"/>\r\n  <link rel="preconnect" href="https://cdn-pci.optimizely.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://s.go-mpulse.net"/>\r\n  <link rel="preconnect" href="https://s.go-mpulse.net" crossorigin/>\r\n\n\t\n\t\t<script type="text/javascript" src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js"></script>\n\t\t<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422"></script>\n    \t\n    \t\t<script type="text/javascript">function OptanonWrapper() {\r\n            if (window.location.pathname.includes(\'customer-service\') &&\r\n                (window.location.pathname.includes(\'en_us\') || window.location.pathname.includes(\'es_us\'))) {\r\n                var newItem = document.createElement("div");\r\n                newItem.id = \'svgButtons\';\r\n\r\n                // Up svg\r\n                const iconSvgUp = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathUp = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgUp.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgUp.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgUp.setAttribute(\'width\', 16);\r\n                iconSvgUp.setAttribute(\'height\', 16);\r\n                iconSvgUp.setAttribute(\'title\', \'Expand Cookie banner\');\r\n                iconPathUp.setAttribute(\r\n                    \'d\',\r\n                    \'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z\'\r\n                );\r\n\r\n                iconPathUp.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)\');\r\n                iconSvgUp.appendChild(iconPathUp);\r\n                iconSvgUp.addEventListener(\'click\', () => handleClick(\'Up\'));\r\n                newItem.appendChild(iconSvgUp);\r\n                iconSvgUp.style.float = \'right\';\r\n\r\n                // Down svg\r\n                const iconSvgDown = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathDown = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgDown.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgDown.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgDown.setAttribute(\'width\', 16);\r\n                iconSvgDown.setAttribute(\'height\', 16);\r\n                iconSvgDown.setAttribute(\'title\', \'Collapse Cookie banner\');\r\n                iconPathDown.setAttribute(\r\n                    \'d\',\r\n                    \'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z\'\r\n                );\r\n\r\n                iconPathDown.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)\');\r\n                iconSvgDown.appendChild(iconPathDown);\r\n                iconSvgDown.addEventListener(\ ...

# %%
# Instanciando objeto Beautiful Soup

soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html class="no-js en-us" lang="en-US">
# <head>
# <link href="https://s1-cdn.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s1-cdn.hm.com" rel="preconnect"/>
# <link href="https://tags.tiqcdn.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://tags.tiqcdn.com" rel="preconnect"/>
# <link href="https://lp2.hm.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://lp2.hm.com" rel="preconnect"/>
# <link href="https://cdn-pci.optimizely.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cdn-pci.optimizely.com" rel="preconnect"/>
# <link href="https://s.go-mpulse.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://s.go-mpulse.net" rel="preconnect"/>
# <script src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-document-language="true" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">function OptanonWrapper() {
#             if (window.location.pathname.includes('customer-service') &&
#                 (window.location.pathname.includes('en_us') || window.location.pathname.includes('es_us'))) {
#                 var newItem = document.createElement("div");
#                 newItem.id = 'svgButtons';
#
#                 // Up svg
#                 const iconSvgUp = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathUp = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgUp.setAttribute('fill', '#222222');
#                 iconSvgUp.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgUp.setAttribute('width', 16);
#                 iconSvgUp.setAttribute('height', 16);
#                 iconSvgUp.setAttribute('title', 'Expand Cookie banner');
#                 iconPathUp.setAttribute(
#                     'd',
#                     'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z'
#                 );
#
#                 iconPathUp.setAttribute(
#                     'transform', 'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)');
#                 iconSvgUp.appendChild(iconPathUp);
#                 iconSvgUp.addEventListener('click', () => handleClick('Up'));
#                 newItem.appendChild(iconSvgUp);
#                 iconSvgUp.style.float = 'right';
#
#                 // Down svg
#                 const iconSvgDown = document.createElementNS('http://www.w3.org/2000/svg', 'svg');
#                 const iconPathDown = document.createElementNS(
#                     'http://www.w3.org/2000/svg',
#                     'path'
#                 );
#
#                 iconSvgDown.setAttribute('fill', '#222222');
#                 iconSvgDown.setAttribute('viewBox', '4 2 8 8');
#                 iconSvgDown.setAttribute('width', 16);
#                 iconSvgDown.setAttribute('height', 16);
#                 iconSvgDown.setAttribute('title', 'Collapse Cookie banner');
#                 iconPathDown.setAttribute(
#                     'd',
#                     'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z'
#                 );
#
#                 iconPathDown.setAttribute(
#                     'transform', 'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)');
#                 iconSvgDown.appendChild(iconPathDown);
#                 iconSvgDown.addEventListener('click', () => handleClick('Down'));
#                 newItem.appendChild(iconSvgDown);
#                 iconSvgDown.style.display = 'none'
#                 iconSvgDown.style.float = 'right';
#                 iconSvgDown.style.marginBottom = '16px';
#
#                 //Adding svg's to the top of title in banner
#                 var list = document.getElementById("onetrust-banner-sdk").childNodes[0];
#                 list.insertBefore(newItem, list.childNodes[0]);
#                 list.style.padding = '20px 40px 40px 40px';
#
#                 document.getElementById('onetrust-group-container').style.display = 'none';
#                 document.getElementById('onetrust-button-group-parent').style.display = 'none';
#
#                 function handleClick(text) {
#                     let buttons = document.getElementById('svgButtons');
#                     if (text === 'Up') {
#                         document.getElementById('onetrust-group-container').style.display = 'block';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'block';
#                         buttons.firstChild.style.display = 'none';
#                         buttons.lastChild.style.display = 'block';
#                     } else {
#                         document.getElementById('onetrust-group-container').style.display = 'none';
#                         document.getElementById('onetrust-button-group-parent').style.display = 'none';
#                         buttons.firstChild.style.display = 'block';
#                         buttons.lastChild.style.display = 'none';
#                     }
#                 }
#             }
#         }</script>
# <link as="script" href="https://s1-cdn.hm.com/global/frontend/loader.js" rel="preload"/>
# <script src="https://s1-cdn.hm.com/global/frontend/loader.js" type="text/javascript"></script>
# <link href="https://s1-cdn.hm.com/global/fonts/4.0.15/hm/css/fonts_en_us.css" rel="stylesheet"/>
# <style type="text/css">/* atf version: 0.19.3 */body{background-color:#faf9f8;margin:0;color:#222;font-family:"HM Sans Regular",sans-serif;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;overflow-x:hidden}body.mobile-app::before{content:"";display:block;position:fixed;width:100%;height:100vh;background-color:#faf9f8;z-index:10000}a{color:inherit}button{border:0;background-color:transparent}.hide-content{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}.header-global{background:#faf9f8;height:30px;left:0;padding:21px 0;top:0;width:100%;z-index:1001}@media(min-width: 768px){.header-global{height:100vh}}.menu{position:relative;display:inline-block;width:100%}.menu a{text-decoration:none}.menu__hm{display:block;width:43px;height:30px;text-indent:-9999px;overflow:hidden;margin:0 0 0 53px}.menu__hm::before{background-image:url("data:image/svg+xml;charset=US-ASCII,%3Csvg%20width%3D%22370%22%20height%3D%22244%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%3E%3Ctitle%3E1.%20Foundation%2FLogotypes%2FH%26amp%3BM%2FRed%3C%2Ftitle%3E%3Cdefs%3E%3Cpath%20d%3D%22M259.895%207.413c13.424-6.618%2020.087-5.737%2020.232.946.19%208.7-1.098%2020.23-2.016%2028.604-4.983%2045.423-13.32%2082.543-13.954%20129.19%2021.94-56.802%2040.345-96.278%2064.03-144.909%207.53-15.47%2012.325-12.593%2018.503-15.343%2024.082-10.715%2024.984-4.133%2021.837%208.95-11.686%2048.552-41.54%20201.376-46.114%20224.907-1.328%206.807-8.715%203.923-10.644%201.26-8.57-11.85-18.225-12.036-17.14-19.919%205.37-39.233%2024.71-137.666%2029.75-160.863-25.719%2052.696-52.37%20118.566-66.053%20155.914-2.907%207.931-8.188%207.35-11.48%201.546-4.63-8.15-13.61-12.312-15.093-21.943-4.702-30.628%205.37-89.003%206.773-125.936-13.994%2040.342-37.49%20118.67-47.782%20154.057-4.256%2014.643-18.382%2012.253-14.627-2.018%2015.642-59.389%2049.326-164.425%2063.915-202.198%203.427-8.874%2012.406-8.569%2019.863-12.245zM174.6.115c4.26%201.025%203.913%206.05%201.31%2012.912-7.682%2020.247-18.335%2046.847-30.516%2078.212%207.658-.874%2011.811-1.17%2011.811-1.17%2010.994-1.358%2013.041%204.139%209.946%209.99-2.466%204.664-5.436%201.554-15.724%2016.89-5.796%208.642-15.259%2010.924-20.515%2012.076-12.662%2033.523-26.23%2070.916-39.415%20110.77-1.919%205.804-7.524%204.532-9.209%202.174-6.192-8.647-10.758-8.933-15.558-15.927-.577-1.132-1.706-2.672-1.027-5.448%203.53-14.425%2012.901-44.067%2027.156-83.091-17.958%203.892-37.387%208.076-45.408%209.94-9.626%2025.445-19.014%2050.967-27.908%2076.18-5.518%2015.64-19.88%2012.617-14.84-2.165%208.028-23.548%2016.89-48.004%2025.776-71.72-9.948-1.063-13.313-8.088-18.873-13.958-2.147-2.267-6.828-1.948-9.12-5.127-4.123-5.711-3.712-8.248%205.81-10.996a955.318%20955.318%200%200%201%2037.464-9.998c16.09-41.524%2030.63-77.144%2038.38-96.151C90.114-1.138%20105.514.226%2099.664%2014.674c-11.889%2029.363-24.079%2059.867-36.11%2090.799a880.98%20880.98%200%200%201%2044.748-8.87%202312.644%202312.644%200%200%201%2034.62-83.968c.845-1.937%203.31-4.678%205.878-5.118%208.092-1.385%2021.251-8.498%2025.8-7.402zm-27.552%20190.077c1.265-.773%202.524-1.715%203.767-2.75a756.514%20756.514%200%200%201-2.82-8.468%20139.528%20139.528%200%200%200-2.752%203.638c-5.386%207.396-2.197%2010.028%201.805%207.58zm7.167-35.065c6.67-7.53-6.516-10.681-3.48.836.17.65.382%201.413.62%202.254a98.19%2098.19%200%200%200%202.86-3.09zm6.941%2022.695c6.602-5.721%2012.908-.046%206.38%209.628-1.404%202.08-2.99%204.318-4.729%206.522a193.17%20193.17%200%200%200%202.146%205.877c3.375%208.654-5.488%2010.824-8.345%203.656-.25-.626-.51-1.297-.778-1.995-5.387%204.772-11.618%207.777-18.275%205.707-10.954-3.407-13.74-18.83-3.514-30.711%204.103-4.767%207.191-8.074%209.771-10.716a251.947%20251.947%200%200%201-1.819-6.17c-1.328-4.81-2.527-10.416%202.287-16.13%209.027-10.712%2029.971-1.203%2019.377%2015.289-2.552%203.972-5.535%207.724-8.647%2011.527a979.555%20979.555%200%200%200%203.2 ...
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.css" type="text/css">
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.js"></script>
# <![endif]-->
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/jquery.min.js"></script>
# <script src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/head.min.14.1.60.js"></script>
# <!-- to include grunticon -->
# <script>var clientlibsVersion = '.14.1.60';</script>
# <!-- to include grunticon -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script async="" src="https://idservice.hm.com/"></script>
# <script type="text/javascript"></script><script src="https://www2.hm.com/optimizelyjs/s/hm_us.js"></script>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <script type="application/ld+json">
#
# 		{
# 		"@context" : "https://schema.org",
# 		"@type" : "BreadcrumbList",
# 		"itemListElement":[
# 		       {"@type":"ListItem",
# 				"position":"1",
# 				"name":"HM.com",
# 				"item": "https://www2.hm.com/en_us/index.html"
# 		        },
#
# 		       {"@type":"ListItem",
# 				"position":"2",
# 				"name":"Loose Jeans"
# 		        }
#
# 		]}
#
# </script>
# <title>Loose Jeans - Light denim blue - Men | H&amp;M US</title>
# <meta content="hmgoe://www2.hm.com/en_us/productpage.1074475001.html" property="al:ios:url">
# <meta content="834465911" property="al:ios:app_store_id"/>
# <meta content="H&amp;M App" property="al:ios:app_name"/>
# <meta content="hmgoe://www2.hm.com/en_us/productpage.1074475001.html" property="al:android:url"/>
# <meta content="com.hm.goe.prd.am" property="al:android:package"/>
# <meta content="H&amp;M" property="al:android:app_name"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="/en_us/productpage" name="contentPath">
# <meta content="5-pocket jeans in sturdy cotton denim with hard-worn details. Loose fit with a regular waist, zip fly and button and wide legs." name="description"/>
# <meta content="Loose Jeans - Light denim blue - Men | H&amp;M US" property="og:title"/>
# <meta content="5-pocket jeans in sturdy cotton denim with hard-worn details. Loose fit with a regular waist, zip fly and button and wide legs." property="og:description"/>
# <meta content="H&amp;M" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F85%2F1f%2F851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BLOOKBOOK%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/main]" name="og:image"/>
# <meta content="https://www2.hm.com/en_us/productpage.1074475001.html" property="og:url"/>
# <meta content="1433700643510498" property="fb:app_id"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www2.hm.com/en_us/productpage.1074475001.html" rel="canonical">
# <script src="/en_us/metrics/default/touchpoint.js" type="text/javascript"></script>
# <script id="product-schema" type="application/ld+json">
# {"@context": "https://schema.org",
# "@type": "Product",
# "itemCondition": "https://schema.org/NewCondition",
# "image": "//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F85%2F1f%2F851f99bd6669fa43c0cbfda8d2b51bfcacd732e0.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BLOOKBOOK%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&call=url[file:/product/main]",
# "name": "Loose Jeans",
# "color": "Light denim blue",
# "description": "5-pocket jeans in sturdy cotton denim with hard-worn details. Loose fit with a regular waist, zip fly and button and wide legs.",
# "sku": "1074475001",
# "brand": {"@type": "Brand","name": "H&M"},
# "category": {"@type": "Thing","name": "Loose"},
# "offers": [{"@type": "Offer","url": "https://www2.hm.com/en_us/productpage.1074475001.html","priceCurrency": "USD",
# "price": "39.99",
# "availability": "http://schema.org/InStock",
# "seller": {  "@type": "Organization", "name": "H&amp;M"}}]}
# </script>
# <meta property="og:open_graph_title">
# <meta property="og:open_graph_description">
# <meta property="og:open_graph_url">
# <meta property="og:open_graph_image">
# <meta property="og:open_graph_video">
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="EPMEN-VPFQ4-GM3WK-22BJD-TU9B7",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"EPMEN-VPFQ4-GM3WK-22BJD-TU9B7";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="fia4weef52naakqce3ybwaabtrrjmbjt-f-61d804b92-clienttons-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"32","ak.cp":"271055","ak.ai":parseInt("171241",10),"ak.ol":"0","ak.cr":42,"ak.ipv":6,"ak.proto":"http/1.1","ak.rid":"68991097","ak.r":36989,"ak.a2":n,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"2a01:cb10:85ee:9a00::","ak.cport":61048,"ak.gh":"92.123.238.85","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1653998899","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"326","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></meta></meta></meta></meta></meta></link></meta></meta></head>
# <script id="esales-content-tmpl" type="text/template">
#   <section class="product-details-recommentation product-items">
#     <header>
#       <h2 class="product-items-title">STYLE WITH</h2>
#     </header>
#
#     <div class="product-items-content{{=it.expose}}">
#       <div class="row swipe">
#         <ul class="swipe-items{{=it.exposeItems}}"></ul>
#       </div>
#
#       <nav class="swipe-navigation swipe-navigation-outer swipe-navigation-dark">
#         <button class="swipe-navigation-prev">
#           <span class="swipe-navigation-prev-inner">Previous</span>
#         </button>
#         <button class="swipe-navigation-next">
#           <span class="swipe-navigation-next-inner">Next</span>
#         </button>
#       </nav>
#     </div>
#   </section>
# </script>
# <script id="saleprice-tmpl" type="text/template">
#   <div class="product-item-price product-item-price-discount">
#     <strong class="price">
#       {{=it.price}}
#       <small class="price-value-original">{{=it.oldPrice}}</small>
#     </strong>
#   </div>
# </script>
# <script id="price-tmpl" type="text/template">
#   <strong class="product-price">
#     {{? it.preshopperPrice }}
#   	<span class="price preshopper">{{=it.preshopperPrice}}</span>
#     {{?? it.salePrice }}
#   	<span class="price sale">{{=it.salePrice}}</span>
#     {{?}}
#   	<span class="price regular">{{=it.regularPrice}}</span>
#   </strong>
# </script>
# <script id="cpi-tmpl" type="text/template">
#   <p class="club-price-text">CLUB PRICE<strong class="club-price">{{=it.price}}</strong></p>
# </script>
# <script id="swatch-tmpl" type="text/template">
#   <li class="item">
#     <a href="{{=it.swatchUrl}}" class="swatch" title="{{=it.swatchName}}" style="background-color: {{=it.swatchHex}};">
#       {{=it.swatchName}}
#     </a>
#   </li>
# </script>
# <script id="esales-new-arrival-tmpl" type="text/template">
#   <span class="product-item-selection">{{=it.text}}</span>
# </script>
# <script id="esales-pagination-tmpl" type="text/template">
#   <ul class="swipe-pagination"></ul>
# </script>
# <script id="esales-pagination-item-tmpl" type="text/template">
#   <li class="swipe-pagination-item">
#     <button class="swipe-pagination-button{{=it.currentClass}}">{{=it.index}}</button>
#   </li>
# </script>
# <script id="mobile-pra-item-tmpl" type="text/template">
#   <div class="grid col-{{=it.colSize}}{{=it.cpiClass}}">
#     <article class="product-item" data-ticket="{{=it.dataTicket}}" data-articlecode="{{=it.articleCode}}" data-index="{{=it.index}}">
#       <a href="{{=it.url}}" class="product-item-link" title="{{=it.name}}">
#         <img class="product-item-image" src="{{=it.src}}" alt="{{=it.name}}">
#       </a>
#       <div class="product-item-details">
#         {{=it.price}}
#         {{=it.cpi}}
#       </div>
#     </article>
#   </div>
# </script>
# <script id="esales-item-tmpl" type="text/template">
#   <div class="grid col-{{=it.colSize}}{{=it.cpiClass}}">
#     <article class="product-item"
#       data-tracking-params='{{=it.dataTrackingParams}}'
#       data-tracking-json-template="{{=it.dataTrackingJsonTemplate}}"
#       data-tracking-type="{{=it.dataTrackingType}}"
#       data-ticket="{{=it.dataTicket}}"
#       data-articlecode="{{=it.articleCode}}"
#       data-index="{{=it.index}}">
#       <a
#         data-event="pra_style_with_click"
#         href="{{=it.url}}"
#         class="product-item-link {{=it.anchorClassName}}"
#         title="{{=it.name}}">
#         <img
#           class="product-item-image"
#           src="{{=it.src}}"
#           alt="{{=it.name}}">
#         {{=it.favourite}}
#       </a>
#       <div class="product-item-details">
#         <h3
#           data-ticket="{{=it.dataTicket}}"
#           data-articlecode="{{=it.articleCode}}"
#           class="product-item-heading">
#           <a
#             class="{{=it.anchorClassName}}"
#             data-event="pra_style_with_click"
#             href="{{=it.url}}"
#             title="{{=it.name}}">
#               {{=it.name}}
#           </a>
#         </h3>
#         {{=it.marketingMarkers}}
#         {{=it.price}}
#         {{=it.cpi}}
#         {{=it.newArrival}}
#         <ul class="list-swatches">
#           {{=it.swatches}}
#         </ul>
#       </div>
#     </article>
#   </div>
#
# </script>
# <script id="blueprice-tmpl" type="text/template">
#   <div class="product-item-price product-item-price-discount product-item-price-blue" style="display:{{=it.display}}">
#     <strong class="price">
#       {{=it.price}}
#       <small class="price-value-original">{{=it.oldPrice}}</small>
#     </strong>
#   </div>
# </script>
# <script id="favourites-inactive-tmpl" type="text/template">
#   <button type="button" class="favorite icon icon-favorites js-favorite" data-saved-text="{{=it.activeText}}" data-not-saved-text="{{=it.inactiveText}}" data-tracking-params="Favourites|{{=it.trackingParams}}">
#     {{=it.inactiveText}}
#   </button>
# </script>
# <script id="text-dismiss-button-modal-content-tmpl" type="text/template">
#   <div aria-hidden="true" class="hidden modal-content">
#     <div class="modal-text">
#       {{? it.heading }}
#       <h1 class="heading">{{= it.heading }}</h1>
#       {{?}}
#       {{? it.subHeading }}
#       <h2 class="sub-heading">{{= it.subHeading }}</h2>
#       {{?}}
#       <p class="text">{{= it.text }}</p>
#     </div>
#     {{? it.button }}
#     <div class="sticky button-group">
#       <button class="button modalclose" type="button">{{= it.button }}</button>
#     </div>
#     {{?}}
#   </div>
# </script>
# <script id="takeover-tmpl" type="text/template">
#     <div class="modal takeover">
#         <button class="modalclose"></button>
#         <div class="modal-wrapper">
#         </div>
#     </div>
# </script>
# <script id="default-modal-tmpl" type="text/template">
#     <div class="modal fadeInModal">
#         <button class="modalclose icon-close-black"></button>
#         <div class="modal-wrapper">
#         </div>
#     </div>
# </script>
# <script id="regular-overlay-tmpl" type="text/template">
#     <div class="modal regular">
#         <button class="modalclose"></button>
#         <div class="modal-wrapper">
#         </div>
#     </div>
# </script><body class="pdp-page">
# <div class="dictionary parbase"></div>
# <script type="text/javascript">
#
#         var hm = hm || {};
#         hm.options = hm.options || {};
#         hm.options.tealiumPageId = 'PRODUCT_DETAIL_PAGE';
#
# </script><!-- Header -->
# <script>
#     var hm = hm || {};
#
#     (function(hm){
#
#     	hm.MultiCountry = function() {
#
#     		function readCookieValue(name) {
#
#     			var cookieAll = document.cookie.split(';'),
#     				cookieValue;
#     			if(cookieAll && cookieAll.length){
#     				cookieAll.some(function(entry){
#     					entry = entry.trim();
#     					var cookiePair = entry.split('=');
#     					if(cookiePair[0]==name){
#     						cookieValue = decodeURIComponent(cookiePair[1]);
#     						return true;
#     					}
#     				});
#     			}
#     			return cookieValue;
#     		};
#
#     		this.getCountryName = function getCountryCode(cookieName) {
#     			var cookieValue = readCookieValue(cookieName);
#     			return cookieValue;
#     		};
#
#     		this.getCountryCode = function getCountryCode(cookieName) {
#
#     			 var cookieValue = readCookieValue(cookieName),
#     				countryCode = "";
#     			if(cookieValue) {
#     				var match = /(?:^[a-z]{2}_)?([A-Z]{2})$/.exec(cookieValue);
#     				if(match) {
#     					countryCode = match[1];
#     				}
#     			}
#     			return countryCode;
#     		};
#
#     		this.getLocale = function getLocale(cookieName, language) {
#
#     		   var locale = "";
#     		   if(!language) {
#     				var cookieValue = readCookieValue(cookieName);
#     				if(cookieValue && cookieValue.search(/^[a-z]{2}_[A-Z]{2}$/) == 0) {
#     					locale = cookieValue;
#     				}
#     		   } else {
#     				var country = this.getCountryCode(cookieName);
#     				if(country.length) {
#     					locale =  language + "_" + country;
#     				}
#     		   }
#     		   return locale;
#     		};
#
#     		this.getLanguage = function getLanguage(cookieName) {
#     		   var language = this.getLocale(cookieName);
#     		   if(!language || !language.length) {
#     				return "";
#     		   }
#     		   else {
#     				return language.substring(0,2);
#     		   }
#     		};
#
#     		this.createCookie = function createCookie(cookieName, language, country) {
#     	        var d = new Date(),
#     			exdays = 182;
#     			d.setTime(d.getTime() + (exdays*24*60*60*1000));
#     			var expires = "expires="+ d.toUTCString();
#     			var userAgent = navigator.userAgent;
#     			var userAgentLowerCase;
#
#     			if(userAgent !== "undefined" && userAgent){
#     				userAgentLowerCase = userAgent.toLowerCase();
# 					if(userAgentLowerCase.includes("chrome")){
# 	    	        	var cookie = cookieName + "=" + language + "_" + country + "; " + expires + ";SameSite=None; Secure; domain=.hm.com; path=/";
# 	    	        } else {
# 						var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	        }
# 	    	    } else {
# 					var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; Secure; path=/";
# 	    	    }
#     	        return cookie;
#     		};
#
#     	};
#
#     	hm.multiCountry = new hm.MultiCountry();
#     })(hm);
#
#
#     hm.options = hm.options || {};
#     hm.options.omnicredit = hm.options.omnicredit || {};
#     hm.options.klarna = hm.options.klarna || {};
#     var wpwlOptions = window.wpwlOptions || {};
#
#     var localeInfo ={};
#     localeInfo.locale = "en_US";
# 	localeInfo.country = "US";
#
#     hm.i18n = hm.i18n || {};
#
#     hm.options.forceUtagForAndroid = false;
#     hm.options.forceUtagForIOS = false;
#
#     hm.options.isLoyaltyMarket = 'true';
#
#     hm.options.isCiamEnabled = 'false';
#
#     hm.options.product = {
#       removeFromCartServiceUrl: 'remove_from_cart_response.json',
#       country: 'hm-us',
#       locale: 'en_us',
#       getFavoritesService: '/en_us/favourites/productCodes',
#       addFavoriteService: '/en_us/favourites/addItem',
#       removeFavoriteService: '/en_us/favourites/removeItem',
# 	  addToCartServiceUrl: '/en_us/cart/add',
# 	  esalesServicePathname: '/pra/panel/product-detail-page',
# 	  clubMemberPriceLabel: 'Member price',
# 	  modelHeightGarmentSizePDPLabel: 'The model is {0} and wears a size {1}',
# 	  sizePDPLabel: 'Size'
#     };
#
#     var productAvailabilityServiceUrl = '/hmwebservices/service/product/{site_code}/availability/{product_code}.json';
# 	var countryForAvailability = hm.options.product.locale;
# 	if(countryForAvailability.indexOf("_")>=0){
# 		countryForAvailability = hm.options.product.locale.split("_")[1];
# 	}
#     productAvailabilityServiceUrl = productAvailabilityServiceUrl.replace("{site_code}",countryForAvailability);
#     hm.options.product.productAvailabilityServiceUrl = productAvailabilityServiceUrl;
#
#     hm.options.clubSetup = {
#     		clubSetupCountry : 'hm-us',
#     		clubSetupTierLevelLimit : '500',
#     		clubSetupCashBackEnabled : 'true',
#     		clubSetupAmount : '5',
#     		clubSetupCashBackCapYear : '99',
#     		clubSetupCashBackCapRolling : '25',
#     		clubSetupCashBackPoints : '200',
#     		clubSetupRatingReviewEnabled : 'false',
#     		clubSetupRatingreview : '0',
#     		clubSetupReviewPointsCapRolling : '0'
#
#     };
#     hm.options.clubUpgrade = {
#     	confirmationMessage: 'You&#039;re now a member!'
#     };
#
#     hm.options.esalesPra10 = {
#     		url: '/en_us/pra/panel/pra10'
#     };
#
#     hm.options.praSlideNoText = {
#    		slideBulletText: '[slideNumberLabel]'
#   	};
#
#     hm.options.gdpr = {
#     	    enabled: 'false',
#     	    dateStart: '2018-05-14T00:00:00.000+02:00',
#     	    dateEnd: '2021-05-01T00:00:00.000+02:00',
#     	    url:'https://www2.hm.com/en_us/customer-service/legal-and-privacy/privacy-link.html'
#     	  };
#
#     hm.options.orders = {
#     	    getOrders: '/mock/getOrders',
#     	    offset: '5',
#     	    missingImageUrl: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/kaff.png'
#     	  };
#     hm.options.pra = {
#     		pra1: '/en_us/pra/panel/product-detail-page',
#     	    pra6: '/en_us/pra/panel/sub-department-page',
#    	     	pra10: '/en_us/pra/panel/pra10',
#     	   	pra11: '/en_us/pra/panel/sale-department-page',
#     	    pra3: '/en_us/pra/panel/shopping-bag-page',
#     	    pra4: '/en_us/pra/panel/shopping-bag-page'
#          };
#     hm.options.omnicredit.isOmnicreditMarket = true;
#
#     hm.options.klarna.showAlerts = true;
#     hm.options.enableQuestionairre = false;
#
#        hm.i18n = {
#        	sizeGuide:  {
# 			   back: 'Back',
# 			   sizeGuide: 'Size Guide',
# 			   findMySize: 'Find my size',
# 			   howToMeasure: 'HOW TO MEASURE',
# 			   selectSizeRange: 'Select Size Range',
# 			   sizeGuideLinkText: 'SIZE GUIDE - ALL PRODUCTS',
# 			   noSizeGuideTitle: 'Oh, hello there!',
# 			   noSizeGuideDescription: 'We don&#039;t have a size guide available for this product at the moment.',
# 			   noSizeGuideClose: 'CLOSE'
# 		},
#    		 favorite: {
#    	   	        favoritesErrorText: 'Sorry, we were unable to move  your item to Favorites. Please try again later.',
#    	   	        addToFavoritesErrorHeading: 'Item not added to Favorites',
#    	   	        removeFavoritesErrorHeading: 'ERROR WHEN REMOVING FAVORITE',
#    	   	        moveToBagErrorHeading: 'Item not moved to your Shopping Bag',
#    	   	     	moveToFavoritesErrorHeading: 'Oops… Favorites is full',
#    	   	    	fullFavoritesListError: 'Sorry, Favorites is full so we can&#039;t add this item. If you really love this item, delete one of your saved items to make room!',
#    	   	        fullFavoritesListErrorHeading: 'Oops… Favorites is full',
#    	   	    	activeText: 'Saved to favorites',
#    	  	      	inactiveText: 'Not saved to favorites'
#    	   	},
#    	 	quickbuy: {
#    	   	      viewMore: 'Show more',
#    	   	      add: 'Add to bag',
#    	   	      selectSize: 'Select size',
#    	   	      fewPiecesLeft: 'Few pieces left',
#    	   	      soldOut: 'Sold out',
#     	 	  sizeGuide: 'Size guide'
#    	   	    },
#    	 	getthelook: {
#    	   	      title: 'Get the look!',
#    	   	      add: 'ADD TO BAG',
#    	   	      addedToBag: 'Added to bag'
#    	   	    },
#    	 	gdpr: {
# 	      	headerText: 'WE CARE ABOUT YOUR PRIVACY!',
#    	  		bodyText:'Your privacy is important to us which is why we want to inform you on our updated Privacy Notice. To give you a more transparent and clear information on how we process your personal data, we have divided the Privacy Notice into different chapters. Depending on if you are a subscriber, member or if you have an H&amp;M Account, different parts of the notice will apply to you. In each chapter, we describe in more detail what personal data we have about you and how we use it. We have also increased the information on your rights, for example how to get access to your data and how you can request to terminate the usage of your data.',
# 	      	linkText: 'You can find our Privacy Notice here',
# 	      	buttonText: 'Ok'
#    		},
# 	    luminaires: {
# 	    		regulationText: 'Regulation (EU) No: 874/2012',
# 	    		energyLabelling: 'Energy rating',
# 	    		compatible: 'This luminaire is compatible with bulbs of energy classes:',
# 	    		energyDeclaration: 'ENERGY RATING',
# 	    		imageNumber: '874/2012'
#
# 	   	},
#     	turnTo: {
# 		    labels: {
# 		    	reviewesLabel: "REVIEWS",
# 		    	finishReview: "FINISH THIS REVIEW",
# 		    	submitReviewCTA: "Send my review",
# 		    	helpHeading: "Help us rate your latest purchase",
# 		    	greeting: "HI",
# 		    	shareExperienceCta: "Share your experience",
# 		    	shareExperienceCtaText: "and help others make great  decisions, please rate your latest purchase",
# 		    	productSatHeading: "Product satisfaction",
# 		    	productSatText: "Rate your product satisfaction",
# 		    	ratingHeading: "Rating",
# 		    	sizeFitHeading: "SIZE AND FIT",
# 		    	myProfileHeading: "My profile",
# 		    	myProfileText: "Help others make great decisions, tell them a little about yourself.",
# 		    	reviewTextLong: "What do you think? People talk about quality, look and feel.",
# 		    	thankYouHeading: "THANK YOU!",
# 		    	thankYouText: "Your feedback is much appreciated",
# 		    	moreReviewCta: "Your reviews are really valuable",
# 		    	moreReviewCta2: "Let&#039;s go for another one!",
# 		    	othersLabel: "What other customers think based on",
# 		    	numberReviews: "{xx} reviews",
# 		    	numberReviewsMenu: "Reviews ({xx})",
# 		    	numberComments: "{xx} comments",
# 		    	othersHeading: "WHAT OTHER CUSTOMERS THINK",
# 		    	userProfileShort: 'in size {size}',
# 		    	commentTitle: 'COMMENT',
# 		    	commentText: 'What do you think? People talk about quality, look and feel.',
# 		    	basedText: "Based on",
# 		    	customerReviews: "customer reviews",
# 		    	basedOnCustomerReviews: "[basedOnCustomerReviews]",
# 		    	boughtLabel: "Bought:",
# 		    	inSizeLabel: "in size",
# 		    	aboutMeLabel: "About me:",
# 		    	showMoreLabel: "Show more",
# 		    	selectedBodyType: "{bodyType} body type",
# 		    	selectedSkinTone: "[skynTone]",
# 		    	selectedSkinType: "{skinType} skin type",
# 		    	filterLabel: "[filter]",
# 		    	sortByLabel: "Sort by",
# 		    	sortOptionLables: [
# 		    		"Most Relevant",
# 		    		"Newest",
# 		    		"Highest Rated",
# 		    		"Lowest Rated"
# 		    	],
# 		    	reviewsDescriptionLabel: "[reviewDescription]",
# 		    	clearAllCta: "[clearAll]",
# 		    	noReviewesHeading: "[noMatchReview]",
# 		    	noReviewesText: "[noReviewText]",
# 		    	colorPurchased: "[purchasedColor]",
# 		    	sizePurchased: "[pushasedSize]",
# 		    	heightLabel: "Height",
# 		    	bodyTypeLabel: "[bodyTypeLabel]",
# 		    	skinToneLabel: "[skinToneLabel]",
# 		    	SkinTypeLabel: "[skinTypeLabel]",
# 		    	labelAll: "All",
# 		    	doneCta: "[done]",
# 		    	clearCta: "[clear]",
# 		    	backCta: "Back",
# 		    	unreviewedItemsPlaceholder: "Your purchased items will show up here, waiting for your review.",
# 		    	unreviewedItemsText: "Let&#039;s leave a review!",
# 		    	itmesCount: "{x} items",
# 		    	leaveReviewCta: "Leave a Review",
# 		    	gotohm: "Go to HM.com",
# 		    	reviewHeading: "REVIEW",
# 		    	shareThoughtsHeading: "SHARE YOUR THOUGHTS ON THIS ITEM!",
# 		    	dimensionText: "What do you think? People talk  about style, occasion and feel.",
# 		    	ratingValidationText: "Your review must include a rating.",
# 		    	maxLengthValidationText: "We&#039;d love to hear your full review, but we&#039;re limited to 5000 characters. Please shorten to post!",
# 		    	unfinishedReviewHeading: "Your review means a lot.",
# 		    	unfinishedReviewtext: "Please finish before you leave. Your changes will not be saved.",
# 		    	unfinishedReviewCta: "Yes, I want to finish",
# 		    	unfinishedReviewExit: "EXIT",
# 		    	shopNowLabel: "SHOP NOW",
# 		    	ratingStarTips: [
# 			    	'Poor',
# 			    	'Fair',
# 			    	'Average',
# 			    	'Good',
# 			    	'Excellent'
# 			    ],
# 			    myhmReviewSection: {
# 		    		noReviewText: 'Your purchased items will show up here, waiting for your review.',
# 				    canReviewText: 'You have {xx} item(s) waiting for your opinion.',
# 					errorText: 'Server error, please try again later.'
# 	        	},
# 			    headlines: {
# 			    	normal: {
# 			    	  title: "REVIEWS",
# 			    	  subTitle: "Tell us what you thought of these items"
# 			    	  },
# 			    	validationError: {
# 			    	  title: "ALMOST THERE!",
# 			    	  subTitle: "Please take a look at what is missing to continue:",
# 			    	  text:  "1. Add rating. 2. Tick Terms of Use box."
# 			    	},
# 			    	connectionError: {
# 			    	  title: "OH, SNAP!",
# 			    	  subTitle: "It looks like you can&#039;t review right now. Please try again later. Thanks for your patience!",
# 			    	  text:  "In the meanwile, head over to our shop!"
# 			    	},
# 			    	NotLoggedIn: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	  text:  ""
# 			    	},
# 			    	reviewFiltersError: {
# 			    	  title: "Sorry",
# 			    	  text: "We could not show any comments about this item at the moment. Please try again in a little while."
# 			    	},
# 			    	oldPurchasedProduct: {
# 			    	  title: "Sorry",
# 			    	  subTitle: "Products were purchased more than {x} days ago and cannot be reviewed.",
# 			    	  text: "However, you can still review below other items that you have bought."
# 			    	},
# 			    	reviewError: {
# 			    	  title: "HI AGAIN!",
# 			    	  subTitle: "YOU HAVE ALREADY REVIEWED THIS ITEM.",
# 			    	  text1: "However, you can still review other items that you have bought below.",
# 			    	  text2: "However, you can always head over to our shop to see what&#039;s trending right now!"
# 			    	},
# 			    	start: {
# 			    	  title: "THANK YOU!",
# 			    	  subTitle: "Your reviews are really valuable",
# 			    	},
# 			    	end: {
# 			    	  title: "YOU&#039;RE THE BEST!",
# 			    	  subTitle: "Your reviews are very valuable",
# 			    	},
# 			    	random: [
# 			    	  "THE MORE THE BETTER!",
# 			    	  "JUST ONE MORE!",
# 			    	  "YES, THIS IS AWESOME!",
# 			    	  "YOU&#039;RE ON A ROLL",
# 			    	  "FLAWLESS!",
# 			    	  "YOU RISE AND SHINE!",
# 			    	  "MORE IS ALWAYS MORE, THANK YOU!",
# 			    	  "DIAMONDS, YOU KEEP ON GIVING!",
# 			    	]
# 	    		},
# 	    		 pointsCommunication: {
# 	                 nonLoggedIn: {
# 	                     copy1: "If you are a member, your points will be awarded if and when your review is published.",
# 	                     copy2: "If you are a member, your points will be awarded if and when your review is published. Not a member yet?{URL} Join now!{/URL}",
# 	                     modalURL: 'join'
# 	                 },
# 	                 clubMember: {
# 	                     copy1: "You&#039;ll earn 0 Points for each item you review — up to 0 products per month.",
# 	                     copy2: "Your points will be awarded if and when your review is published.",
# 	                     copy3: "You&#039;ll earn points for every review!",
# 	                     copy4: "Your points will be awarded if and when your review is published."
# 	                 },
# 	                 nonClubMember: {
# 	                     copy1: "If you {URL}become a member{/URL}, you can earn points when you review an item — collect enough points and you&#039;ll receive a bonus to use for future purchases.",
# 	                     copy2: "Don&#039;t forget to {URL}become a Loyalty Member{/URL} — you can earn points for leaving reviews! Collect enough points and you&#039;ll receive a reward to use on future purchases!",
# 	                     copy3: "Did you know Members earn points for product reviews and get exclusive offers and rewards? Join now, it’s free!",
# 	                     copy4: "Become a member",
# 	                     modalURL: 'club-upgrade'
# 	                 }
# 	             },
# 		    	continueShoppingBtn: {
# 			    	text: "Continue Shopping",
#                     urlLink: "/en_us/index.html"
# 			    },
# 			    joinClubBtn: {
# 			        text: "Become a member",
# 			        remodalTriggerId: "club-upgrade"
# 			    },
#     		},
# 		    showMoreBtn: {
# 	        	text: "Show More Products"
# 	      	}
#     	},
#     	notifyIfBack: {
#     		notifyMeButton: 'NOTIFY ME',
#     		notifyMeButton_text: 'Notify me',
#     		notifyMeList: 'Notify me',
#     		notifyMeListMessage: 'Get notified when your size is back.',
# 	        outOfStock: 'Out of stock',
# 	        moveToBag: '[moveToBag]',
# 	        modal: {
# 	          select: {
# 	            heading: 'KEEP ME POSTED',
# 	            info: 'If your product comes back in stock, we&#039;ll email you.',
# 	            pickSize: 'Size',
# 	            selectSize: 'Select size',
# 	            notify: 'WE WILL NOTIFY YOU AT:',
# 	            disclaimer: 'Your request will be saved for 3 months.',
# 	            button: 'NOTIFY ME',
# 	            heading_text: 'Keep me posted',
# 	            info_text: 'We&#039;ll let you know if the product comes back in stock.',
# 	            button_text: 'Notify me',
# 	            reminderFormTitle_text: 'Notify me by:',
# 	            emailMethodLabel_text: 'Email',
# 	            phoneMethodLabel_text: 'Text',
# 	            bothMethodLabel_text: 'Email and text',
# 	            emailLabel_text: 'Email*',
# 	            phoneLabel_text: 'Phone*',
# 	            invalidPhoneNumber_text: 'Invalid phone number',
# 	            invalidEmailAddress_text: 'Invalid email address',
# 	            warningInfo_text: '{0}',
# 	            warningInfoPhone_text: '*Your phone number will only be used to contact you about the product you requested. Standard carrier rates apply. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.',
# 	            warningInfoEmail_text: '*Your email will only be used to contact you about the product you requested. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.',
# 	            warningInfoFull_text: '*Your phone number and email will only be used to contact you about the product you requested. We will process your personal data in accordance with H&amp;M&#039;s {0}Privacy Notice{1}.'
# 	          },
# 	          success: {
# 	            heading: 'YOU&#039;RE ALL SET',
# 	            info: 'If your product comes back in stock, we&#039;ll email you at {0}',
# 	            button: 'Continue Shopping',
# 	            heading_text: 'We&#039;ll notify you via the email or phone number below if your size comes back in stock:'
# 	          },
# 	          error: {
# 	            heading: 'OH NO!',
# 	            info: 'For some reason, we couldn&#039;t register your notification request.',
# 	            button: 'TRY AGAIN'
# 	          },
# 	          login: {
# 	            heading: 'DON&#039;T MISS OUT!',
# 	            info: 'Get notified if your product comes back in stock — it&#039;s easy!',
# 	            text: 'Simply sign in and click on &#039;Notify Me&#039; and you&#039;ll receive a notification if this product comes back again.',
# 	            button: 'Sign in / join'
# 	          }
# 	        }
# 	      },
# 		video: {
# 			'playButtonText' : 'Play video',
# 			'pauseButtonText' : 'Pause video',
# 			'closeButtonText' : 'Close video',
# 			'videoErrorTitle' : 'Oops!',
# 			'videoErrorText' : 'Seems like we&#039;re having trouble loading this video',
# 			'videoReloadText' : 'Reload',
# 			'videoLoadingText' : 'Video player is loading now'
# 		},
#     	searchImgAlt: {
# 	    	washTag: 'Wash Tag',
# 	    	priceTag: 'Price Tag'
#     	},
#     	confirm: 'OK',
# 	    general: {
# 	    	next: 'Next',
# 	    	previous: 'Previous',
# 	    	close: 'Close',
# 	    	all: 'All',
# 	    	enableContrastMode: 'Enable high-contrast mode',
# 	    	disableContrastMode: 'Disable high-contrast mode',
# 	    	hm: 'H&amp;M',
# 	    	hennes: 'Hennes &amp; Mauritz'
#     	},
#     	pdp: {
# 	    	artNo: 'Art. No.',
# 	    	soldOut: 'Sold out',
# 	    	fewPiecesLeft: 'Few pieces left',
# 	    	comingSoon: 'Coming soon',
# 	    	comingSoonButton: 'COMING SOON'
#     	},
#     	product: {
#     		newArrivalText: 'New Arrival'
#     	},
#     	completeRegistration: '[pleaseCompleteRegistration]',
#         giftCard: {
#         	servicedown: 'Service Down'
#         },
#         sustainability: {
#             starterButton: 'PRODUCT BACKGROUND',
#             modalTitle: 'PRODUCT BACKGROUND',
#             introText: 'We believe that greater transparency will help lead the change towards a more sustainable future. As a step in this long-term commitment, we’re sharing how and where our products are made wherever possible. ',
#             introTextNoSuppliers: 'We believe that greater transparency will help lead the change towards a more sustainable fashion future. As a first step in this long-term commitment, we’re sharing how our products are made wherever possible.',
#             materials: {
#               headerText: 'MATERIALS',
#               bodyText: 'Our goal is to use 100% recycled or other sustainably sourced materials by 2030.'
#             },
#             suppliers: {
#               headerText: 'OUR SUPPLIERS',
#               backText: "Back",
#               bodyTextCountryList: 'This product has been produced in one of the following countries:',
#               buttonSeeAllText: 'Suppliers and factories for this product.',
#               introText: 'All of our products are made by independent suppliers, often in developing countries where our presence can make a real difference. Our business helps to create jobs and independence, particularly for women — consequently lifting people out of poverty and contributing to economic growth.   We only work with partners who share our respect for people and the environment, and who are willing to work with us to improve their practices. All suppliers and factories must sign our strict Sustainability Commitment, which includes requirements for fair wages and good working conditions for all. We employ a dedicated sustainability staff in our worldwide production offices to make sure the commitment is followed.',
#               sorryText: 'Unfortunately, supplier and factory information isn’t currently available for this product. Thank you for being patient while we work towards displaying these details for all H&amp;M items possible.',
#               modalTitle: 'SUPPPLIER &amp; FACTORY LIST',
#               workersAmount: 'Number of workers:',
#               disclaimerTop: 'These suppliers and factories made this product for H&amp;M globally, which means that the item you will receive is produced by one of these suppliers and one of their factories.',
#               disclaimerLabelsupplierAndFactoryExplanationText: 'We want to be completely transparent with you about how and where our products are made, therefore we have a new system for this.',
#               disclaimerLabelsupplierAndFactoryExplanationText_2: 'However, if an item was produced before we started using our new system, all of the supplier information may not be available. We’re focusing our efforts on making sure all items going forward, display all supplier details.',
# ...
# <button class="button large js-submit-clubjoin" type="submit">Become a member</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="remodal-content-wrapper" data-remodal-content-id="terms-and-conditions-for-club" data-remodal-options="escape:false, popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/en_us/_jcr_content/clubtermsandconditions.modal.html, additionalClasses: popup-logo-header, closeButton: false">
# </div>
# <div class="globalmodals parbase">
# <div data-remodal-content-id="terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="termsconditions-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacypolicy-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-notice" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-policy" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-link.modal.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-privacy">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="privacy-direct-marketing" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-direct-marketing-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# <div class="remodal-content"></div>
# </div>
# <div data-remodal-content-id="privacy-policy-fashion" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/legal-and-privacy/privacy-notice-hm-account-link.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/dataprocessing.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-overseastransfer" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/overseastransfer.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-thirdpartytransfer" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/third-party-transfer.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="personal-data-info-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/data-usage-info.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="marketing-information-consent" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/consent-of-personal-data/marketing-and-receive-advertising-information.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <div data-remodal-content-id="hmclub-terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/en_us/customer-service/h-m-club/h-m-club-terms-conditions.modal.html, ajaxHTMLSelector:.article-contents">
# <header class="remodal-header">
# </header>
# </div>
# <!-- Modal content for the account access   -->
# <div data-remodal-content-id="accountaccess-popup" data-remodal-options="ajaxUrl:/en_us/customer-service/dontagreepage.modal.html, popup: true, additionalClasses: account-access">
# <header class="remodal-header">
# <h2 class="heading">
# </h2>
# </header>
# <div class="remodal-content"></div>
# </div>
# </div>
# </div></footer><!-- /Footer -->
# <script>
# if(isPreshoppingActive()==undefined || isPreshoppingActive()== null || isPreshoppingActive()== ""){
# 	document.cookie = "preshoppingUser="+false;
# } else{
# 	document.cookie = "preshoppingUser="+true;
# }
#
#
# function trackVideoPlay(articleCode)
# {
#
#
# 	hm.Tracking.link({
# 		event_type: 'PDP_INTERACTION_VIDEO',
# 		event_id : 'Start video',
# 		event_category: 'Product interactions',
# 		event_label: articleCode.toString()
# 	});
# }
#
# function trackAddToCart(articleCode, sizeCode, articlePrice, articleRedPrice, articleBluePrice, clubPrice, isCartStarter, isFewPieceLeft, turnTo, averageRating, ugc, sustainabilityClicked) {
#     var tp = getTouchpoint();
# 	var cc = productArticleDetails[articleCode].colorCode;
#     var price = articlePrice;
#     var area = "";
#     var type = "";
#     var articleCodes = [];
# 	var avgRating = "";
# 	var prdRating="FALSE";
#    	if(typeof(utag_data.page_osa_area) != "undefined" && typeof(utag_data.page_osa_type) != "undefined"){
#    		area = utag_data.page_osa_area;
#         type = utag_data.page_osa_type;
#     }
# 	var productPriceType = '';
# 	if (articleRedPrice !== null) {
# 		price = articleRedPrice;
# 		productPriceType = 'SALES_PRICE';
# 	}
# 	if (isPreshoppingActive() && articleBluePrice !== null) {
# 		price = articleBluePrice.replace(/[^\d\.,]/g, '');
# 		productPriceType = 'PRE_SHOPPING_PRICE';
# 	}
# 	if (isFullMember() && (clubPrice !== null && clubPrice !== undefined)) {
# 		price = clubPrice.replace(/[^\d\.,]/g, '');
# 		productPriceType = 'CLUB_PRICE';
# 	}
# 	var isCartStarterString = isCartStarter?"true":"false";
# 	articleCodes.push(articleCode);
#
# 	if (averageRating === 0 ){
# 		avgRating = "0.0";
# 	}else{
# 		prdRating="TRUE";
# 		avgRating = averageRating;
# 	}
#
# 	var productSizeRec = sessionStorage.getItem('recsize-' + hm.product.getProductId()) || 'No recommendation available';
# 	var productHasVideo = !!(window.productArticleDetails[articleCode] && window.productArticleDetails[articleCode].video.videoId);
# 	var productSize = '';
# 	var productHasVideo = '';
# 	var productBrandName = "H&M";
# 	if (typeof(utag_data.product_video) !== 'undefined'){
# 		productHasVideo = utag_data.product_video;
# 	}
#
# 	if (window.productArticleDetails[articleCode] && window.productArticleDetails[articleCode].sizes) {
# 	    var _productSize = window.productArticleDetails[articleCode].sizes.filter(function(item) {
# 	        return item.size === sizeCode;
# 	    })[0];
# 	    if (_productSize) {
# 	        productSize = _productSize.name;
# 	    }
#
# 	}
#
#
# 		productBrandName = 'H&M';
#
#
#     hm.Tracking.link({	page_id : 'PRODUCT_DETAIL : 1074475 : LOOSE RIPPED',
#                touchpoint : tp,
#                category_id : 'MEN_JEANS_LOOSE',
#                category_path : 'PRODUCT_DETAIL_PAGE',
#                display_language : "en_US",
#                selected_market : "US",
#                product_id : ['1074475'],
#                product_name : ['LOOSE RIPPED'],
#                product_currency : 'USD',
#                product_quantity : ['1'],
#                product_list_price : [price],
#                product_original_price : [articlePrice],
#                product_category : ['MEN_JEANS_LOOSE'],
#                product_price_type: [productPriceType],
#                product_color_code : [cc],
#                product_size_code : [sizeCode],
#                product_osa_area : [area],
#                product_osa_type : [type],
#                sb_id : '',
#                sb_empty : isCartStarterString,
#                order_id : '',
#                order_subtotal : '',
#                event_type : 'ADD_TO_BAG',
#                product_article_id: articleCodes,
#                product_cart_starter : [isCartStarterString.toUpperCase()],
#                product_few_pieces : [isFewPieceLeft.toString().toUpperCase()],
#                product_ugc : [ugc.toString().toUpperCase()],
#                product_rating : [prdRating.toString().toUpperCase()],
#                product_rating_avg : [avgRating],
#                product_sustainability : sustainabilityClicked ? ["TRUE"] :["FALSE"],
#                product_size: [productSize],
#                product_size_rec: [productSizeRec],
#                product_video : productHasVideo ? ['TRUE'] :['FALSE'],
#                product_marker_marketing : utag_data.product_marker_marketing ? utag_data.product_marker_marketing : ['Conscious choice  '],
#                product_marker_selection : utag_data.product_marker_selection ? utag_data.product_marker_selection : ['New Arrival'],
#                imp_origin_system: utag_data && utag_data.imp_origin_system ? utag_data.imp_origin_system : '',
#                product_virtual_category: utag_data && utag_data.product_virtual_category ? utag_data.product_virtual_category : '',
#                product_brand : [productBrandName]
#               });
#     sendNotification('en_us',articleCode, 'add-to-cart', 'PDP');
# }
#
# function getOsaArea(){
# 	var areaAttr = "osa_area_1074475001";
# 	var osaArea = "";
# 	if(sessionStorage){
# 		osaArea = sessionStorage.getItem(areaAttr);
# 		sessionStorage.removeItem(areaAttr);
# 	}else if(localStorage){
# 		osaArea = localStorage.getItem(areaAttr);
# 		localStorage.removeItem(areaAttr);
# 	}
# 	if(osaArea == null){
# 		osaArea = "";
# 	}
# 	return osaArea;
# }
# function getOsaType(){
# 	var typeAttr = "osa_type_1074475001";
# 	var osaType = "";
# 	if(sessionStorage){
# 		osaType = sessionStorage.getItem(typeAttr);
# 		sessionStorage.removeItem(typeAttr);
# 	}else if(localStorage){
# 		osaType = localStorage.getItem(typeAttr);
# 		localStorage.removeItem(typeAttr);
# 	}
# 	if(osaType == null){
# 		osaType = "";
# 	}
# 	return osaType;
# }
# function getVirtualCategory(){
# 	var vcAttr = "vc_1074475001";
# 	var virtualCategory = "";
# 	if(sessionStorage){
# 		virtualCategory = sessionStorage.getItem(vcAttr);
# 		sessionStorage.removeItem(vcAttr);
# 	}else if(localStorage){
# 		virtualCategory = localStorage.getItem(vcAttr);
# 		localStorage.removeItem(vcAttr);
# 	}
# 	if(virtualCategory == null){
# 		virtualCategory = "";
# 	}
# 	return virtualCategory;
# }
# function isPreshoppingActive(){
# 	return hm.options.isPreshopperUser;
# }
# function isFullMember(){
# 	var memberInfo = JSON.parse(localStorage.getItem("localStorageMemberInfo"));
# 	if(memberInfo!= "undefined" && memberInfo != null && memberInfo.status=='FULL_MEMBER'){
# 		return true;
# 	}
# 	return false;
# }
# </script>
# <div class="tealiumProductviewtag productview parbase"><script type="text/javascript">var osaArea = getOsaArea(); var osaType = getOsaType(); var virtualCategory = getVirtualCategory(); utag_data = {product_id : ["1074475"], product_article_id : ["1074475001"], product_name : ["LOOSE RIPPED"], product_view_type : "PDP",product_view_price_type: [""], product_category : ["MEN_JEANS_LOOSE"], product_color_code : ["74"], product_currency : ["USD"], product_size_code : [""], page_osa_area : osaArea, page_osa_type : osaType, product_virtual_category : virtualCategory,  product_original_price : ["39.99"], product_video : ["FALSE"], product_list_price :  ["39.99"], product_marker_marketing : ["Conscious choice  "], product_marker_selection : ["New Arrival"], product_brand : ["H&M"], event_type  : "", customer_id : "", customer_email : "", customer_zip : "", customer_city : "", customer_state : "", customer_state : "", customer_country : "", customer_loyalty_level : "", customer_has_children : "", customer_fashion_news : "" , touchpoint : getTouchpoint() , page_id : "PRODUCT DETAIL : 1074475 : LOOSE RIPPED", category_id : "MEN_JEANS_LOOSE", category_path : "PRODUCT_DETAIL_PAGE", selected_market : "US", display_language : "en_US", event_type  : "", customer_id : "", customer_email : "", customer_zip : "", customer_city : "", customer_state : "", customer_state : "", customer_country : "", customer_loyalty_level : "", customer_has_children : "", customer_fashion_news : "" }; utagTealiumTrack(function(a,b,c,d){var forceUtagLogic = (hm.device.iPhone() && hm.options.forceUtagForIOS) || (hm.device.android() && hm.options.forceUtagForAndroid);    if(!hm.device.app() || (hm.device.app() && forceUtagLogic ) ){a=getTealiumURL("US");b=document;c='script';d=b.createElement(c);d.src=a;d.id='utagMainScript';d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);}}); </script> </div>
# <div class="nuancechat nuanceChat parbase">
# <div id="Nuance-chat-anchored"></div>
# <script async="" charset="utf-8" src="https://hm-us.inq.com/chatskins/launch/inqChatLaunch10006533.js" type="text/javascript"></script>
# <script>
# 	  hm.waitUntil(function() {
# 			return hm.version;
# 		}).then(function() {
# 			hm.cookies = hm.cookies || new hm.Cookies();
# 			var nuanceData={};
# 			window.nuanceData = nuanceData;
# 			if(hm.cookies && hm.cookies.readCookie('userCookie')){
# 				var userCookieVal = JSON.parse(hm.cookies.readCookie('userCookie'));
# 				if (userCookieVal){
#
# 					if(userCookieVal.cartCount>=0){
# 						nuanceData["cartCount"] = userCookieVal.cartCount;
# 					}
# 				if(userCookieVal.dominantCategory){
# 						nuanceData["dominantCategory"] = userCookieVal.dominantCategory;
# 					}
# 					if(userCookieVal.cartProducts){
# 						nuanceData["cartProducts"] = userCookieVal.cartProducts;
# 					}
# 					if(userCookieVal.hybris_firstName){
# 						nuanceData["hybris_firstName"] = decodeURIComponent((userCookieVal.hybris_firstName + '').replace(/\+/g, '%20'));
# 					}
# 					if(userCookieVal.hybris_uuid){
# 						nuanceData["hybris_uuid"] = userCookieVal.hybris_uuid;
# 					}
# 					if(userCookieVal.customer_id){
# 						nuanceData["customer_id"] = userCookieVal.customer_id;
# 					}
# 					if(userCookieVal.type){
# 						nuanceData["type"] = userCookieVal.type;
# 					}
# 					if(userCookieVal.str){
# 						nuanceData["st"] = decodeURIComponent(userCookieVal.str.replaceAll(/\+/g, ' '));
# 					}
# 					if(userCookieVal.zc){
# 						var val = userCookieVal.zc.replace(/[+,-]/g," ");
# 							nuanceData["zc"] = val;
# 				}
# 					if(userCookieVal.tn){
# 						nuanceData["tn"] = decodeURIComponent(userCookieVal.tn.replaceAll(/\+/g, ' '));
# 					}
# 				}
# 			}
# 			var favouritesCookie = hm.options.product.country + "-favourites";
#
# 			var hasFav = hm.cookies.readCookie("hm-austria-favourites");
# 			if(hasFav && !(hasFav==="\"\"")){nuanceData["hm-country-favourites"] = hasFav;}
# 			console.log(nuanceData);
# 		});
# 		</script>
# <script type="text/javascript">
# 			// Click on Chat icon
# 			$(document).on("click", "#Nuance-chat-anchored", function() {
# 				hm.Tracking.link({
# 					event_type : 'AI_CHAT_INITIATE',
# 					event_id : 'Click on Start AI chat',
# 					event_category : 'AI Chat',
# 					event_label : hm.options.tealiumPageId
# 				});
#
# 				console.log(document.URL);
# 			});
# 		</script>
# </div>
# <script src="/B2hlry7V/Geuh4Bm/V75v13g/WC/EObiSbmz/XiljaAMMfAM/UggoL/A8GUGA" type="text/javascript"></script></body></html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Color name

soup.find_all('li', class_='list-item')
# Out:
# [<li class="list-item">
#  <a class="link" data-remodal-trigger="signin-account" href="/en_us/account">My Account</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" data-remodal-trigger="join" href="#">Not a Member yet? Join here!</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/account">My Account</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/member/info.html">Loyalty Program Info</a>
#  </li>,
#  <li class="list-item">
#  <a class="link" href="/en_us/logout" onclick="trackLogout()">Sign out</a>
#  </li>,
#  <li class="list-item">
#  <a aria-checked="true" class="filter-option miniature active" data-articlecode="1074475001" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1074475001.html" id="filter-colour-1074475001" role="radio" title="Light denim blue">
#  <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>
#  </li>]

# %%
# Primeiro elemento do list item
soup.find_all('li', class_='list-item')[0]
# Out:
# <li class="list-item">
# <a class="link" data-remodal-trigger="signin-account" href="/en_us/account">My Account</a>
# </li>

# %%
soup.find_all('a', class_='filter-option miniature active')[0]
# Out:
# <a aria-checked="true" class="filter-option miniature active" data-articlecode="1074475001" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1074475001.html" id="filter-colour-1074475001" role="radio" title="Light denim blue">
# <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
# <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
# </noscript>
# <span></span>
# </a>

# %%
soup.find_all('a', class_='filter-option miniature active')[0].get('data-color')
# Out:
# 'Light denim blue'

# %%
product_list = soup.find_all('a', class_='filter-option miniature active')

# %%
color_name = [p.get('data-color') for p in product_list]
color_name
# Out:
# ['Light denim blue']

# %%
product_list[0]
# Out:
# <a aria-checked="true" class="filter-option miniature active" data-articlecode="1074475001" data-color="Light denim blue" data-sizes="" href="/en_us/productpage.1074475001.html" id="filter-colour-1074475001" role="radio" title="Light denim blue">
# <noscript data-alt="Light denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
# <img alt="Light denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fe6%2Ffe%2Fe6fedc2bef692e5ad2ec9c48d71832c36c498b29.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5B%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
# </noscript>
# <span></span>
# </a>

# %%
product_id_c = [p.get('data-articlecode') for p in product_list]

# %%
product_id_c
# Out:
# ['1074475001']

# %%
df_color = pd.DataFrame([product_id_c, color_name]).T
df_color
# Out:
#             0                 1
# 0  1074475001  Light denim blue

# %%
df_color.columns = ['product_id', 'color_name']

# %%
df_color.head()
# Out:
#    product_id        color_name
# 0  1074475001  Light denim blue
